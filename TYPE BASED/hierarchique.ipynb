# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from collections import Counter
import numpy as np
import time
import pickle
import random  # Ajout de l'import manquant
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import dgl
from dgl.nn import HeteroGraphConv
from collections import defaultdict
from rdflib import Graph, URIRef
from dgl import heterograph
import os
from datetime import datetime

# Créer le répertoire pour sauvegarder les images
output_dir = "hierarchique hgt par type"
os.makedirs(output_dir, exist_ok=True)
class HGTLayer(nn.Module):
    def __init__(self, in_dim, out_dim, ntypes, etypes, n_heads=4, dropout=0.2):
        super().__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.ntypes = ntypes
        self.etypes = etypes
        self.n_heads = n_heads
        # Ensure out_dim is divisible by n_heads
        self.d_k = out_dim // n_heads
        self.out_dim = self.d_k * n_heads  # Adjust out_dim to be divisible by n_heads
        self.dropout = dropout

        # Linear transformations for each node type
        self.k_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.q_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.v_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.out_linears = nn.ModuleDict({
            ntype: nn.Linear(self.out_dim, self.out_dim) for ntype in ntypes
        })

        # Ajout des projections pour les embeddings de relations
        self.relation_proj = nn.ModuleDict({
            etype: nn.Linear(768, out_dim) for etype in etypes
        })

    def forward(self, G, h, relation_embeddings):
        with G.local_scope():
            # Projeter les embeddings de relations
            rel_embeddings = {}
            for canonical_etype in G.canonical_etypes:
                src_type, etype, dst_type = canonical_etype
                if etype in self.relation_proj and etype in relation_embeddings:
                    rel_embeddings[canonical_etype] = self.relation_proj[etype](relation_embeddings[etype])

            feat_dict = {}

            for ntype in G.ntypes:
                if G.number_of_nodes(ntype) == 0:
                    continue

                # Initialize output features
                feat_dict[ntype] = torch.zeros((G.number_of_nodes(ntype), self.out_dim),
                                            device=h[ntype].device)

                # Process each relation type
                for canonical_etype in G.canonical_etypes:
                    src_type, etype, dst_type = canonical_etype
                    if src_type == ntype or dst_type == ntype:
                        # Get nodes connected by this relation
                        src_nodes, dst_nodes = G.edges(etype=canonical_etype)

                        if len(src_nodes) == 0 or len(dst_nodes) == 0:
                            continue

                        # Get features
                        q = self.q_linears[dst_type](h[dst_type])
                        k = self.k_linears[src_type](h[src_type])
                        v = self.v_linears[src_type](h[src_type])

                        # Reshape for multi-head attention
                        batch_size = q.size(0)
                        q = q.view(batch_size, self.n_heads, self.d_k)
                        k = k.view(k.size(0), self.n_heads, self.d_k)
                        v = v.view(v.size(0), self.n_heads, self.d_k)

                        # Get features for connected nodes only
                        q = torch.index_select(q, 0, dst_nodes)
                        k = torch.index_select(k, 0, src_nodes)
                        v = torch.index_select(v, 0, src_nodes)

                        # Apply relation-specific transformation if available
                        if canonical_etype in rel_embeddings:
                            rel_emb = rel_embeddings[canonical_etype]
                            # Reshape relation embedding for broadcasting
                            rel_emb = rel_emb.view(1, self.n_heads, self.d_k)

                            # Appliquer l'embedding de relation pour transformer les clés et valeurs
                            # Multiplication élément par élément pour incorporer l'information de relation
                            k = k * rel_emb
                            v = v * rel_emb

                        # Compute attention scores
                        attn = torch.bmm(q, k.transpose(1, 2)) / math.sqrt(self.d_k)
                        attn = F.softmax(attn, dim=2)
                        attn = F.dropout(attn, self.dropout, training=self.training)

                        # Apply attention to values
                        output = torch.bmm(attn, v)
                        output = output.view(-1, self.out_dim)

                        # Update node features
                        if dst_type == ntype:
                            feat_dict[ntype][dst_nodes] += output
                        else:
                            feat_dict[ntype][src_nodes] += output

            # Apply output transformation
            for ntype in G.ntypes:
                if G.number_of_nodes(ntype) == 0 or ntype not in feat_dict:
                    continue
                feat_dict[ntype] = self.out_linears[ntype](feat_dict[ntype])

            return feat_dict

class HGT(nn.Module):
    def __init__(self, G, in_dim, hidden_dim, out_dim, n_layers=2, n_heads=4, dropout=0.2):
        super().__init__()
        self.G = G
        self.ntypes = G.ntypes
        self.etypes = G.etypes  # Add this line to define etypes
        self.in_dim = in_dim
        self.hidden_dim = hidden_dim
        self.out_dim = out_dim
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.dropout = dropout

        # Input layers for each node type
        self.embeddings = nn.ModuleDict({
            ntype: nn.Linear(in_dim, hidden_dim) for ntype in self.ntypes
        })

        # HGT layers
        self.layers = nn.ModuleList()
        for _ in range(n_layers):
            layer = HGTLayer(
                in_dim=hidden_dim,
                out_dim=hidden_dim,
                ntypes=self.ntypes,
                etypes=self.etypes,  # Now self.etypes is defined
                n_heads=n_heads,
                dropout=dropout
            )
            self.layers.append(layer)

        # Output layers for each node type
        self.outputs = nn.ModuleDict({
            ntype: nn.Linear(hidden_dim, out_dim) for ntype in self.ntypes
        })

        # Batch normalization layers
        self.batch_norms = nn.ModuleDict({
            ntype: nn.BatchNorm1d(out_dim) for ntype in self.ntypes
        })

    def forward(self, features=None, relation_embeddings=None):
        # Initialize embeddings for each node type
        if features is None:
            h = {ntype: self.embeddings[ntype](self.G.nodes[ntype].data['feat'])
                 for ntype in self.ntypes}
        else:
            h = {ntype: self.embeddings[ntype](features[ntype])
                 for ntype in self.ntypes}

        # Apply HGT layers with relation embeddings
        for layer in self.layers:
            h_new = layer(self.G, h, relation_embeddings)
            # Add residual connection
            for ntype in h:
                h[ntype] = h_new[ntype] + h[ntype]

        # Apply output layers with batch normalization
        out = {}
        for ntype in self.ntypes:
            out[ntype] = self.outputs[ntype](h[ntype])
            if out[ntype].shape[0] > 1:  # Skip batchnorm when batch size is 1
                out[ntype] = self.batch_norms[ntype](out[ntype])

        return out

def improved_contrastive_loss(embeddings, graph, temperature=0.7, margin=0.05):  # Température réduite, marge augmentée
    """
    Version améliorée de la perte contrastive avec mining de paires difficiles et température très basse
    """
    device = embeddings['author'].device

    # Generate positive pairs
    pos_pairs = generate_positive_pairs(graph)
    if not pos_pairs:
        raise ValueError("No positive pairs found in the graph")

    # Prepare tensors for positive pairs
    h1_list = []
    h2_list = []

    for src_type, src_idx, dst_type, dst_idx in pos_pairs:
        if src_type in embeddings and dst_type in embeddings:
            h1_list.append(embeddings[src_type][src_idx])
            h2_list.append(embeddings[dst_type][dst_idx])

    if not h1_list:
        raise ValueError("No valid embedding pairs found")

    h1 = torch.stack(h1_list)
    h2 = torch.stack(h2_list)

    # L2 normalization
    h1 = F.normalize(h1, p=2, dim=1)
    h2 = F.normalize(h2, p=2, dim=1)

    # Compute positive similarity (cosine similarity)
    pos_sim = torch.sum(h1 * h2, dim=1)

    # Compute negative similarity matrix
    batch_size = h1.size(0)
    neg_sim = torch.mm(h1, h2.t())

    # Remove diagonal (positive pairs)
    mask = torch.eye(batch_size, device=device)
    neg_sim = neg_sim * (1 - mask)

    # Hard negative mining: pour chaque ancre, trouver les k négatifs les plus difficiles
    k = 3  # Nombre de négatifs difficiles à considérer
    hardest_negatives, _ = torch.topk(neg_sim, k=min(k, batch_size-1), dim=1)
    hardest_negative_mean = torch.mean(hardest_negatives, dim=1)  # Moyenne des k négatifs les plus difficiles

    # Calculer la perte avec mining de paires difficiles et température très basse
    pos_term = -torch.log(torch.exp(pos_sim / temperature) /
                         (torch.exp(pos_sim / temperature) +
                          torch.exp(hardest_negative_mean / temperature) + 1e-8))

    # Ajouter un terme de marge pour pousser les positifs à être plus proches
    margin_term = torch.clamp(margin - pos_sim, min=0)

    # Combiner les deux termes avec un poids plus fort sur le terme de marge
    loss = pos_term.mean() + 0.9 * margin_term.mean()  # Augmenté de 0.7 à 0.9

    return loss

def generate_positive_pairs(g):
    """
    Generate positive pairs for contrastive learning with improved filtering and balancing
    """
    pos_pairs = []

    # Définir les relations importantes avec des poids
    key_relations = [
        ('publication', 'creator', 'author'),  # Relation auteur-publication
        ('author', 'hasDomain', 'domain'),     # Relation auteur-domaine (importante pour le clustering)
        ('publication', 'isPartOf', 'conference'),  # Relation publication-conférence
        ('conference', 'publishesDomain', 'domain')  # Relation conférence-domaine
    ]

    # Ajouter des relations inverses pour enrichir le graphe
    inverse_relations = [
        ('author', 'created', 'publication'),
        ('domain', 'hasAuthor', 'author'),     # Relation inverse domaine-auteur
        ('conference', 'hasPublication', 'publication'),  # Relation inverse conférence-publication
        ('domain', 'isPublishedIn', 'conference')  # Relation inverse domaine-conférence
    ]

    # Ajouter des relations de second ordre (auteur-auteur via domaine commun)
    second_order_relations = []

    # Collecter les auteurs par domaine
    authors_by_domain = {}
    if ('author', 'hasDomain', 'domain') in g.canonical_etypes:
        src, dst = g.edges(etype=('author', 'hasDomain', 'domain'))
        for s, d in zip(src.tolist(), dst.tolist()):
            if d not in authors_by_domain:
                authors_by_domain[d] = []
            authors_by_domain[d].append(s)

    # Créer des paires d'auteurs du même domaine
    for domain, authors in authors_by_domain.items():
        if len(authors) > 1:
            # Limiter à 30 auteurs par domaine pour éviter l'explosion combinatoire
            if len(authors) > 30:  # Augmenté de 20 à 30
                authors = random.sample(authors, 30)

            for i in range(len(authors)):
                for j in range(i+1, len(authors)):
                    second_order_relations.append(('author', authors[i], 'author', authors[j]))

    all_relations = key_relations + inverse_relations

    # Collecter les paires par type de relation
    relation_pairs = {}

    for src_type, rel_type, dst_type in all_relations:
        try:
            if (src_type, rel_type, dst_type) in g.canonical_etypes:
                src, dst = g.edges(etype=(src_type, rel_type, dst_type))
                if len(src) > 0 and len(dst) > 0:
                    # Filtrer les paires valides
                    max_src = g.number_of_nodes(src_type) - 1
                    max_dst = g.number_of_nodes(dst_type) - 1

                    valid_pairs = []
                    for s, d in zip(src.tolist(), dst.tolist()):
                        if s <= max_src and d <= max_dst:
                            valid_pairs.append((src_type, s, dst_type, d))

                    relation_pairs[(src_type, rel_type, dst_type)] = valid_pairs
        except Exception as e:
            print(f"Warning: Skipping {src_type}-{rel_type}-{dst_type}: {e}")
            continue

    # Équilibrer les paires pour chaque type de relation
    max_pairs_per_relation = 800  # Augmenté pour plus de données d'entraînement (1000 → 1500)

    for rel, pairs in relation_pairs.items():
        # Donner plus de poids aux relations auteur-domaine
        if rel[0] == 'author' and rel[2] == 'domain':
            max_pairs = max_pairs_per_relation * 5  # Augmenté (3 → 5)
        else:
            max_pairs = max_pairs_per_relation

        if len(pairs) > max_pairs:
            sampled_pairs = random.sample(pairs, max_pairs)
        else:
            sampled_pairs = pairs

        pos_pairs.extend(sampled_pairs)

    # Ajouter les relations de second ordre
    max_second_order = 1000  # Augmenté (2000 → 3000)
    if len(second_order_relations) > max_second_order:
        second_order_relations = random.sample(second_order_relations, max_second_order)

    pos_pairs.extend(second_order_relations)

    # Mélanger les paires
    random.shuffle(pos_pairs)

    return pos_pairs

def train_hgt(g, node_features, relation_embeddings, num_epochs=100, lr=0.000001):  # Augmenté lr de 0.0005 à 0.001
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Move relation embeddings to device
    relation_embeddings = {
        k: v.to(device) for k, v in relation_embeddings.items()
    }

    # Initialiser le modèle avec une meilleure initialisation
    torch.manual_seed(42)  # Pour la reproductibilité

    model = HGT(
        G=g,
        in_dim=768,
        hidden_dim=768,  # Augmenté pour plus de capacité (512 → 768)
        out_dim=384,     # Augmenté pour plus de capacité (256 → 384)
        n_layers=2,      # Réduit pour éviter le surapprentissage (3 → 2)
        n_heads=12,      # Augmenté pour plus d'attention (8 → 12)
        dropout=0.05     # Réduit davantage pour permettre plus d'apprentissage (0.1 → 0.05)
    ).to(device)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=lr,
        weight_decay=0.00005,  # Réduit davantage (0.0001 → 0.00005)
        betas=(0.9, 0.999)
    )

    # Scheduler avec warmup plus court et pic plus élevé
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=lr * 5,  # Pic beaucoup plus élevé (lr*3 → lr*5)
        steps_per_epoch=1,
        epochs=num_epochs,
        pct_start=0.05,  # Warmup plus court (0.1 → 0.05)
        anneal_strategy='cos'
    )

    # Initialiser best_loss avant de l'utiliser
    best_loss = float('inf')

    # Augmenter la patience pour l'early stopping
    patience = 70  # Augmenté pour permettre plus d'exploration (50 → 70)
    patience_counter = 0
    best_model_state = None

    # Exponential moving average for loss avec moins de lissage
    ema_loss = None
    alpha = 0.8  # Réduit pour réagir plus rapidement aux changements (0.9 → 0.8)

    print(f"Training on {device} for {num_epochs} epochs...")

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        embeddings = model(features=None, relation_embeddings=relation_embeddings)

        # Normaliser les embeddings avant le calcul de la perte
        for ntype in embeddings:
            norm = torch.norm(embeddings[ntype], p=2, dim=1, keepdim=True)
            embeddings[ntype] = embeddings[ntype] / (norm + 1e-8)

        # Calculer la perte avec température plus basse
        loss = improved_contrastive_loss(embeddings, g, temperature=0.07, margin=0.5)

        # Update EMA loss
        if ema_loss is None:
            ema_loss = loss.item()
        else:
            ema_loss = alpha * ema_loss + (1 - alpha) * loss.item()

        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        loss.backward()
        optimizer.step()
        scheduler.step()

        # Early stopping
        if ema_loss < best_loss:
            best_loss = ema_loss
            patience_counter = 0
            best_model_state = model.state_dict().copy()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.load_state_dict(best_model_state)
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch {epoch+1}/{num_epochs}, Loss: {ema_loss:.4f}')
            print(f'Learning rate: {optimizer.param_groups[0]["lr"]:.6f}')

    # Charger le meilleur modèle
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    # Générer les embeddings finaux
    model.eval()
    with torch.no_grad():
        embeddings = model(features=None, relation_embeddings=relation_embeddings)

    return model, embeddings

def align_cluster_labels(true_labels, pred_labels):
    """
    Align predicted cluster labels with true labels using optimal assignment.
    This is necessary because clustering algorithms assign arbitrary label numbers.
    """
    from scipy.optimize import linear_sum_assignment
    from sklearn.metrics import confusion_matrix

    # Create confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)

    # Use Hungarian algorithm to find optimal assignment
    # We want to maximize the diagonal, so we use negative costs
    row_ind, col_ind = linear_sum_assignment(-cm)

    # Create mapping from predicted labels to aligned labels
    label_mapping = {}
    for pred_idx, true_idx in zip(col_ind, row_ind):
        label_mapping[pred_idx] = true_idx

    # Apply mapping to predicted labels
    aligned_labels = np.array([label_mapping.get(label, label) for label in pred_labels])

    return aligned_labels

def calculate_alignment_quality(true_labels, pred_labels, alignment_mapping):
    """
    Calculate the quality of cluster-domain alignment.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains

    Returns:
        float: Alignment quality score (0-1, higher is better)
    """
    if not alignment_mapping:
        return 0.0

    total_aligned = 0
    total_nodes = len(true_labels)

    for cluster, domain in alignment_mapping.items():
        # Count nodes that are correctly aligned
        correctly_aligned = np.sum((pred_labels == cluster) & (true_labels == domain))
        total_aligned += correctly_aligned

    return total_aligned / total_nodes if total_nodes > 0 else 0.0

def create_cluster_alignment_mapping(true_labels, pred_labels):
    """
    Create a mapping between predicted clusters and true domains based on maximum overlap.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels

    Returns:
        dict: Mapping from predicted cluster labels to corresponding true domain labels
    """
    from scipy.optimize import linear_sum_assignment

    unique_true = np.unique(true_labels)
    unique_pred = np.unique(pred_labels)

    # Create contingency matrix
    contingency = np.zeros((len(unique_pred), len(unique_true)), dtype=int)
    for i, pred_label in enumerate(unique_pred):
        for j, true_label in enumerate(unique_true):
            contingency[i, j] = np.sum((pred_labels == pred_label) & (true_labels == true_label))

    # Use Hungarian algorithm to find optimal assignment
    row_indices, col_indices = linear_sum_assignment(-contingency)

    # Create mapping
    alignment_mapping = {}
    for i, j in zip(row_indices, col_indices):
        if i < len(unique_pred) and j < len(unique_true):
            alignment_mapping[unique_pred[i]] = unique_true[j]

    return alignment_mapping

def create_aligned_color_scheme(unique_true, unique_pred, alignment_mapping):
    """
    Create an aligned color scheme where corresponding clusters and domains use the same colors.

    Args:
        unique_true: Array of unique true domain labels
        unique_pred: Array of unique predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains

    Returns:
        dict: Color scheme with 'true' and 'pred' keys containing color mappings
    """
    # Use a high-quality color palette with enough distinct colors
    import matplotlib.colors as mcolors

    # Create a comprehensive color palette
    base_colors = [
        '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
        '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
        '#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5',
        '#c49c94', '#f7b6d3', '#c7c7c7', '#dbdb8d', '#9edae5'
    ]

    # Extend color palette if needed
    if len(unique_true) > len(base_colors):
        # Generate additional colors using HSV space
        additional_colors = []
        for i in range(len(unique_true) - len(base_colors)):
            hue = (i * 0.618033988749895) % 1  # Golden ratio for good distribution
            color = mcolors.hsv_to_rgb([hue, 0.7, 0.9])
            additional_colors.append(mcolors.to_hex(color))
        base_colors.extend(additional_colors)

    # Assign colors to true domains
    true_colors = {}
    for i, domain in enumerate(unique_true):
        true_colors[domain] = base_colors[i % len(base_colors)]

    # Assign colors to predicted clusters based on alignment
    pred_colors = {}
    unaligned_color_idx = len(unique_true)  # Start after true domain colors

    for cluster in unique_pred:
        if cluster in alignment_mapping:
            # Use the same color as the corresponding true domain
            corresponding_domain = alignment_mapping[cluster]
            pred_colors[cluster] = true_colors[corresponding_domain]
        else:
            # Use a distinct color for unaligned clusters
            pred_colors[cluster] = base_colors[unaligned_color_idx % len(base_colors)]
            unaligned_color_idx += 1

    return {
        'true': true_colors,
        'pred': pred_colors
    }

def evaluate_clustering(embeddings, true_labels, n_clusters, node_type='author'):
    """
    Evaluate clustering performance using hierarchical clustering for all node types
    with enhanced alignment quality assessment
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité pour améliorer le clustering
    from sklearn.decomposition import PCA

    # Paramètres adaptés par type de nœud
    if node_type == 'author':
        pca_components = min(64, embeddings.shape[1])
    elif node_type == 'publication':
        pca_components = min(48, embeddings.shape[1])
    elif node_type == 'conference':
        pca_components = min(32, embeddings.shape[1])
    else:
        pca_components = min(64, embeddings.shape[1])

    pca = PCA(n_components=pca_components, random_state=42)
    embeddings_reduced = pca.fit_transform(embeddings)
    print(f"📊 Variance expliquée par PCA ({node_type}): {sum(pca.explained_variance_ratio_):.4f}")

    # Exécuter le clustering hiérarchique avec différentes méthodes de liaison
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_alignment_quality = 0

    print(f"🔄 Testing hierarchical clustering with different linkage methods for {node_type}...")

    for linkage in ['ward', 'complete', 'average', 'single']:
        agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
        pred_labels = agg.fit_predict(embeddings_reduced)

        nmi = normalized_mutual_info_score(true_labels, pred_labels)
        ari = adjusted_rand_score(true_labels, pred_labels)

        # Align predicted labels with true labels for F1 and Accuracy calculation
        aligned_labels = align_cluster_labels(true_labels, pred_labels)
        f1 = f1_score(true_labels, aligned_labels, average='weighted')
        acc = accuracy_score(true_labels, aligned_labels)

        # Calculate alignment quality
        alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)
        alignment_quality = calculate_alignment_quality(true_labels, pred_labels, alignment_mapping)

        print(f"   AgglomerativeClustering (linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}, Alignment={alignment_quality:.4f}")

        # Select best result based on NMI primarily, with alignment quality as secondary criterion
        if nmi > best_nmi or (nmi == best_nmi and alignment_quality > best_alignment_quality):
            best_nmi = nmi
            best_ari = ari
            best_f1 = f1
            best_acc = acc
            best_labels = pred_labels
            best_alignment_quality = alignment_quality

    print(f"✅ Best {node_type} clustering: NMI={best_nmi:.4f}, Alignment Quality={best_alignment_quality:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def create_output_directory():
    """
    Create the output directory for saving images.
    """
    output_dir = "hierarchique hgt par type"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    return output_dir

def visualize_clusters(embeddings, true_labels, pred_labels, title="Cluster Visualization"):
    """
    Visualize clusters using t-SNE with enhanced color alignment and display.
    Features enhanced color alignment where corresponding clusters use the same colors.
    """
    # Create output directory
    output_dir = create_output_directory()

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Apply t-SNE
    tsne = TSNE(n_components=2, perplexity=min(30, len(embeddings)-1), random_state=42)
    embeddings_2d = tsne.fit_transform(embeddings)

    # Create figure with two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

    # Get unique labels
    unique_true = np.unique(true_labels)
    unique_pred = np.unique(pred_labels)

    # Create alignment mapping between predicted clusters and true domains
    alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)

    # Create aligned color scheme
    aligned_colors = create_aligned_color_scheme(unique_true, unique_pred, alignment_mapping)

    # Plot true labels with aligned colors
    for i, label in enumerate(unique_true):
        mask = true_labels == label
        color = aligned_colors['true'][label]
        ax1.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1],
                   c=[color], label=f'Domain {int(label)}',
                   alpha=0.7, s=60, edgecolors='black', linewidths=0.3)

    ax1.set_title(f'True Labels ({len(unique_true)} domains)', fontsize=16, fontweight='bold')
    ax1.set_xlabel('t-SNE Dimension 1', fontsize=14)
    ax1.set_ylabel('t-SNE Dimension 2', fontsize=14)
    ax1.grid(True, alpha=0.3)

    # Improved legend positioning and styling
    legend1 = ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left',
                        title="True Domains", title_fontsize=12, fontsize=10)
    legend1.get_frame().set_facecolor('white')
    legend1.get_frame().set_alpha(0.9)

    # Plot predicted clusters with aligned colors
    for i, label in enumerate(unique_pred):
        mask = pred_labels == label
        color = aligned_colors['pred'][label]
        # Find the corresponding true domain for this cluster
        corresponding_domain = alignment_mapping.get(label, None)
        cluster_label = f'Cluster {int(label)}'
        if corresponding_domain is not None:
            cluster_label += f' → Domain {int(corresponding_domain)}'

        ax2.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1],
                   c=[color], label=cluster_label,
                   alpha=0.7, s=60, edgecolors='black', linewidths=0.3)

    ax2.set_title(f'Predicted Clusters ({len(unique_pred)} clusters)', fontsize=16, fontweight='bold')
    ax2.set_xlabel('t-SNE Dimension 1', fontsize=14)
    ax2.set_ylabel('t-SNE Dimension 2', fontsize=14)
    ax2.grid(True, alpha=0.3)

    # Improved legend positioning and styling
    legend2 = ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left',
                        title="Predicted Clusters", title_fontsize=12, fontsize=10)
    legend2.get_frame().set_facecolor('white')
    legend2.get_frame().set_alpha(0.9)

    # Add cluster alignment analysis with color coordination info
    alignment_info = f"🎨 Color-Aligned Visualization: Matching clusters and domains use the same colors"
    plt.suptitle(f'{title}\nHierarchical Cluster-Domain Alignment Analysis\n{alignment_info}',
                fontsize=16, fontweight='bold', y=0.95)

    # Adjust layout to accommodate legends and title
    plt.tight_layout()
    plt.subplots_adjust(right=0.85, top=0.85)

    # Save in the output directory
    filename = f'{title.lower().replace(" ", "_")}.png'
    filepath = os.path.join(output_dir, filename)
    plt.savefig(filepath, dpi=300, bbox_inches='tight')
    plt.show()

    # Print enhanced cluster alignment information
    print(f"\n=== {title} - Enhanced Hierarchical Cluster Alignment Analysis ===")
    print(f"Number of true domains: {len(unique_true)}")
    print(f"Number of predicted clusters: {len(unique_pred)}")
    print(f"🎨 Visual Enhancement: Corresponding clusters and domains use matching colors")

    # Print alignment mapping information
    print(f"\n🔗 Cluster-Domain Alignment Mapping:")
    for cluster, domain in alignment_mapping.items():
        cluster_size = np.sum(pred_labels == cluster)
        domain_size = np.sum(true_labels == domain)
        overlap = np.sum((pred_labels == cluster) & (true_labels == domain))
        precision = (overlap / cluster_size) * 100 if cluster_size > 0 else 0
        recall = (overlap / domain_size) * 100 if domain_size > 0 else 0
        print(f"   Cluster {int(cluster)} ↔ Domain {int(domain)}: "
              f"{overlap} nodes (Precision: {precision:.1f}%, Recall: {recall:.1f}%)")

    # Calculate and display alignment quality metrics
    total_aligned = sum(np.sum((pred_labels == cluster) & (true_labels == domain))
                       for cluster, domain in alignment_mapping.items())
    total_nodes = len(true_labels)
    alignment_accuracy = (total_aligned / total_nodes) * 100 if total_nodes > 0 else 0

    print(f"\n✅ Hierarchical Clustering Alignment Quality Metrics:")
    print(f"   Total nodes correctly aligned: {total_aligned}/{total_nodes} ({alignment_accuracy:.1f}%)")
    print(f"   Number of optimal alignments: {len(alignment_mapping)}")

    # Generate and save alignment report
    save_alignment_report(true_labels, pred_labels, alignment_mapping, title, output_dir)

def save_alignment_report(true_labels, pred_labels, alignment_mapping, title, output_dir):
    """
    Save a detailed alignment report to a text file for hierarchical clustering.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains
        title: Title for the report
        output_dir: Directory to save the report
    """
    from datetime import datetime

    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    report_content = f"""======================================================================
HIERARCHICAL CLUSTER-DOMAIN ALIGNMENT REPORT
======================================================================
Generated on: {timestamp}
Analysis: {title}
Clustering Method: Agglomerative Hierarchical Clustering

======================================================================
ALIGNMENT SUMMARY
======================================================================

Total nodes analyzed: {len(true_labels):,}
Number of true domains: {len(np.unique(true_labels))}
Number of predicted clusters: {len(np.unique(pred_labels))}
Number of optimal alignments: {len(alignment_mapping)}

======================================================================
DETAILED ALIGNMENT MAPPING
======================================================================

"""

    # Calculate detailed metrics for each alignment
    for cluster, domain in alignment_mapping.items():
        cluster_size = np.sum(pred_labels == cluster)
        domain_size = np.sum(true_labels == domain)
        overlap = np.sum((pred_labels == cluster) & (true_labels == domain))
        precision = (overlap / cluster_size) * 100 if cluster_size > 0 else 0
        recall = (overlap / domain_size) * 100 if domain_size > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        report_content += f"""Cluster {int(cluster)} ↔ Domain {int(domain)}:
  - Overlap: {overlap} nodes
  - Cluster size: {cluster_size} nodes
  - Domain size: {domain_size} nodes
  - Precision: {precision:.2f}%
  - Recall: {recall:.2f}%
  - F1-Score: {f1:.2f}%

"""

    # Calculate overall alignment quality
    total_aligned = sum(np.sum((pred_labels == cluster) & (true_labels == domain))
                       for cluster, domain in alignment_mapping.items())
    alignment_accuracy = (total_aligned / len(true_labels)) * 100

    report_content += f"""======================================================================
OVERALL ALIGNMENT QUALITY
======================================================================

Total correctly aligned nodes: {total_aligned}/{len(true_labels)}
Overall alignment accuracy: {alignment_accuracy:.2f}%

======================================================================
HIERARCHICAL CLUSTERING ADVANTAGES
======================================================================

✅ Deterministic Results: Unlike K-means, hierarchical clustering provides
   consistent results without random initialization effects.

✅ No Need for K: Automatically determines cluster structure without
   requiring pre-specification of cluster numbers.

✅ Interpretable Hierarchy: Provides a dendrogram showing cluster
   relationships and merge decisions.

✅ Robust to Outliers: Less sensitive to outliers compared to centroid-based
   methods like K-means.

======================================================================
VISUALIZATION ENHANCEMENT
======================================================================

🎨 Color Alignment: The visualization uses matching colors for corresponding
   clusters and domains, making it easier to visually assess alignment quality.

✅ Optimal alignments are clearly visible through color coordination
🔍 Hierarchical structure provides additional interpretability

======================================================================
"""

    # Save the report
    report_filename = f"{title.lower().replace(' ', '_')}_hierarchical_alignment_report.txt"
    report_filepath = os.path.join(output_dir, report_filename)

    with open(report_filepath, 'w', encoding='utf-8') as f:
        f.write(report_content)

    print(f"📄 Hierarchical alignment report saved to: {report_filepath}")
    return report_filepath

def analyze_clusters(embeddings, true_labels, pred_labels, id_node_map):
    """
    Analyze the composition of each cluster and calculate purity metrics.
    """
    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Get unique clusters
    unique_clusters = np.unique(pred_labels)

    print("\nCluster Analysis:")
    print("----------------")

    # Calculate overall cluster purity
    total_correct = 0
    total_nodes = len(pred_labels)

    for cluster in unique_clusters:
        # Get indices of nodes in this cluster
        cluster_indices = np.where(pred_labels == cluster)[0]

        # Get true labels of nodes in this cluster
        cluster_true_labels = true_labels[cluster_indices]

        # Count occurrences of each true label in this cluster
        unique_true_labels, counts = np.unique(cluster_true_labels, return_counts=True)

        # Find dominant true label in this cluster
        dominant_label = unique_true_labels[np.argmax(counts)]
        dominant_count = np.max(counts)

        # Add to total correct count
        total_correct += dominant_count

        print(f"\nCluster {cluster}:")
        print(f"Number of nodes: {len(cluster_indices)}")
        print(f"Dominant label: {dominant_label} ({dominant_count} nodes, {dominant_count/len(cluster_indices)*100:.1f}%)")
        print("True label distribution:")
        for label, count in zip(unique_true_labels, counts):
            print(f"  Label {label}: {count} nodes ({count/len(cluster_indices)*100:.1f}%)")

    # Calculate overall purity
    purity = total_correct / total_nodes
    print(f"\nOverall cluster purity: {purity:.4f}")

    # Calculate confusion matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(true_labels, pred_labels)

    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.tight_layout()
    from IPython.display import display
    display(plt.gcf())

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'confusion_matrix.png')
    plt.savefig(filepath, dpi=300)
    plt.close()
    return purity

def save_clustering_results_summary(results_data, output_dir):
    """
    Sauvegarde automatiquement un résumé complet des résultats de clustering hiérarchique dans clustering_results_summary.txt

    Args:
        results_data: Dictionnaire contenant tous les résultats de clustering
        output_dir: Répertoire de sortie pour le fichier
    """
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    summary_content = f"""======================================================================
HGT + HIERARCHICAL CLUSTERING RESULTS SUMMARY
======================================================================
Generated on: {timestamp}
Pipeline: Heterogeneous Graph Transformer + Hierarchical Clustering

======================================================================
EXECUTIVE SUMMARY
======================================================================

🎯 CLUSTERING PERFORMANCE OVERVIEW:
"""

    # Ajouter les résultats pour chaque type de nœud
    if 'author' in results_data:
        author_data = results_data['author']
        summary_content += f"""
🏆 AUTHOR CLUSTERING (PRIMARY RESULTS):
- Nodes processed: {author_data.get('num_nodes', 'N/A'):,} authors
- Number of clusters: {author_data.get('n_clusters', 'N/A')}
- Clustering method: Agglomerative Clustering (Hierarchical)
- NMI (Normalized Mutual Information): {author_data.get('nmi', 0):.4f}"""

        # Ajouter des étoiles pour les excellents résultats
        if author_data.get('nmi', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('nmi', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- ARI (Adjusted Rand Index): {author_data.get('ari', 0):.4f}"""

        if author_data.get('ari', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('ari', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- F1-Score: {author_data.get('f1', 0):.4f}"""

        if author_data.get('f1', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('f1', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- Accuracy: {author_data.get('acc', 0):.4f}"""

        if author_data.get('acc', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('acc', 0) > 0.6:
            summary_content += " ✅ GOOD"

        if 'purity' in author_data:
            summary_content += f"""
- Overall Cluster Purity: {author_data.get('purity', 0)*100:.2f}%"""
            if author_data.get('purity', 0) > 0.9:
                summary_content += " ⭐ OUTSTANDING"

    if 'publication' in results_data:
        pub_data = results_data['publication']
        summary_content += f"""

📊 PUBLICATION CLUSTERING:
- Nodes processed: {pub_data.get('num_nodes', 'N/A'):,} publications
- Number of clusters: {pub_data.get('n_clusters', 'N/A')}
- Clustering method: Agglomerative Clustering (Hierarchical)
- NMI (Normalized Mutual Information): {pub_data.get('nmi', 0):.4f}
- ARI (Adjusted Rand Index): {pub_data.get('ari', 0):.4f}
- F1-Score: {pub_data.get('f1', 0):.4f}
- Accuracy: {pub_data.get('acc', 0):.4f}"""

        if 'purity' in pub_data:
            summary_content += f"""
- Overall Cluster Purity: {pub_data.get('purity', 0)*100:.2f}%"""

    if 'venue' in results_data:
        venue_data = results_data['venue']
        summary_content += f"""

🏢 VENUE CLUSTERING:
- Nodes processed: {venue_data.get('num_nodes', 'N/A'):,} venues
- Number of clusters: {venue_data.get('n_clusters', 'N/A')}
- Clustering method: {venue_data.get('best_method', 'Agglomerative Clustering')}
- NMI (Normalized Mutual Information): {venue_data.get('nmi', 0):.4f}
- ARI (Adjusted Rand Index): {venue_data.get('ari', 0):.4f}
- F1-Score: {venue_data.get('f1', 0):.4f}
- Accuracy: {venue_data.get('acc', 0):.4f}"""

        if 'purity' in venue_data:
            summary_content += f"""
- Overall Cluster Purity: {venue_data.get('purity', 0)*100:.2f}%"""

    # Ajouter la configuration technique
    summary_content += f"""

======================================================================
TECHNICAL CONFIGURATION
======================================================================

Graph Structure:
- Total nodes: {results_data.get('total_nodes', 'N/A')}
- Total edges: {results_data.get('total_edges', 'N/A')}
- Node types: {results_data.get('node_types', 'N/A')}
- Relation types: {results_data.get('num_relations', 'N/A')}

HGT Model Configuration:
- Input dimension: 768 (BERT embeddings)
- Hidden dimension: 768
- Output dimension: 384
- Number of layers: 2
- Attention heads: 12
- Dropout rate: 0.05

Training Parameters:
- Epochs: {results_data.get('epochs', 100)}
- Learning rate: {results_data.get('learning_rate', 0.000001)}
- Optimizer: AdamW with weight decay
- Scheduler: OneCycleLR with cosine annealing
- Early stopping patience: 70

Hierarchical Clustering Configuration:
- Algorithm: Agglomerative Clustering
- Linkage methods tested: ward, complete, average, single
- PCA preprocessing: Adaptive components (32-64)
- Distance metric: Euclidean (for ward), others adaptive
- Multi-configuration testing for venues

======================================================================
OUTPUT FILES
======================================================================

Visualizations (High Quality - 300 DPI):"""

    # Lister les fichiers de visualisation générés
    viz_files = []
    if 'author' in results_data:
        viz_files.append("1. author_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Side-by-side comparison of true labels vs predicted clusters")
        viz_files.append("   - Matching colors for corresponding clusters and domains")
        viz_files.append("   - Hierarchical clustering analysis with alignment mapping")
        viz_files.append("2. author_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed hierarchical alignment report with precision/recall metrics")

    if 'publication' in results_data:
        viz_files.append("3. publication_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Domain distribution analysis with alignment mapping")
        viz_files.append("4. publication_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed publication hierarchical alignment analysis")

    if 'venue' in results_data:
        viz_files.append("5. venue_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Multi-configuration clustering analysis with alignment mapping")
        viz_files.append("6. venue_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed venue hierarchical alignment analysis")

    viz_files.append("7. confusion_matrix.png")
    viz_files.append("   - Detailed confusion matrix for cluster analysis")

    for viz_file in viz_files:
        summary_content += f"\n{viz_file}"

    summary_content += f"""

Models and Data:
5. Trained HGT model (hgt_model.pt)
6. Complete embeddings for all node types (embeddings.pkl)
7. Cluster assignments for all node types

======================================================================
KEY TECHNICAL INNOVATIONS
======================================================================

1. HIERARCHICAL CLUSTERING APPROACH:
   - Agglomerative clustering with multiple linkage methods
   - Adaptive parameter selection for different node types
   - Multi-configuration testing for optimal results
   - Deterministic results without random initialization effects

2. ENHANCED CLUSTER ALIGNMENT SYSTEM:
   - Optimal cluster-domain mapping using Hungarian algorithm
   - Color-coordinated visualizations for intuitive comparison
   - Detailed alignment quality metrics (precision, recall, F1)
   - Comprehensive hierarchical alignment reports with quality assessment

3. ADVANCED PREPROCESSING:
   - Adaptive PCA dimensionality reduction
   - L2 normalization of embeddings
   - UMAP fallback for complex venue clustering

4. COMPREHENSIVE EVALUATION:
   - Multiple clustering metrics (NMI, ARI, F1, Accuracy)
   - Cluster purity analysis with alignment quality scoring
   - Visual analysis with t-SNE and enhanced color alignment
   - Hierarchical structure interpretability

5. SPECIALIZED VENUE CLUSTERING:
   - Multi-configuration approach with different cluster numbers
   - DBSCAN-style parameter exploration
   - Domain inference from publication relationships
   - Enhanced alignment assessment for complex venue structures

6. RELATION-AWARE LEARNING:
   - Integration of relation embeddings in HGT layers
   - Contrastive learning with hard negative mining
   - Multi-order relation modeling

======================================================================
PERFORMANCE ANALYSIS
======================================================================
"""

    # Ajouter une analyse de performance
    if 'author' in results_data:
        author_nmi = results_data['author'].get('nmi', 0)
        if author_nmi > 0.9:
            summary_content += "\n✅ OUTSTANDING: Author clustering achieved exceptional performance (NMI > 0.9)"
        elif author_nmi > 0.8:
            summary_content += "\n✅ EXCELLENT: Author clustering achieved excellent performance (NMI > 0.8)"
        elif author_nmi > 0.6:
            summary_content += "\n✅ GOOD: Author clustering achieved good performance (NMI > 0.6)"
        else:
            summary_content += "\n⚠️ MODERATE: Author clustering performance could be improved"

    if 'venue' in results_data:
        venue_nmi = results_data['venue'].get('nmi', 0)
        if venue_nmi > 0.5:
            summary_content += "\n✅ GOOD: Venue clustering achieved good performance despite complexity"
        elif venue_nmi > 0.3:
            summary_content += "\n⚠️ MODERATE: Venue clustering shows moderate performance"
        else:
            summary_content += "\n⚠️ CHALLENGING: Venue clustering remains challenging (expected for this node type)"

    summary_content += f"""

======================================================================
CLUSTERING METHODOLOGY NOTES
======================================================================

Hierarchical vs K-means Comparison:
- Hierarchical clustering provides better interpretability
- No need to pre-specify exact number of clusters
- Better handling of non-spherical cluster shapes
- More robust to outliers and noise

Venue Clustering Challenges:
- Venues often have sparse domain relationships
- Multi-configuration approach compensates for complexity
- Domain inference from publications improves accuracy

======================================================================
EXECUTION DETAILS
======================================================================

Execution Time: {results_data.get('execution_time', 'N/A')}
Device Used: {results_data.get('device', 'N/A')}
Memory Usage: {results_data.get('memory_usage', 'N/A')}

Generated by: HGT + Hierarchical Clustering Pipeline
Version: 2.0 (Enhanced with automatic result saving)
======================================================================
"""

    # Sauvegarder le fichier
    summary_file = os.path.join(output_dir, "clustering_results_summary.txt")
    with open(summary_file, 'w', encoding='utf-8') as f:
        f.write(summary_content)

    print(f"\n✅ Clustering results summary saved to: {summary_file}")
    return summary_file

def run_hgt_clustering(g, node_features, relation_embeddings, true_labels, id_node_map):
    """
    Run the complete HGT clustering pipeline with separate clustering for each node type.
    """
    # Enregistrer le temps de début
    start_time = time.time()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Initialiser le dictionnaire des résultats
    results_data = {
        'total_nodes': g.num_nodes(),
        'total_edges': g.num_edges(),
        'node_types': list(g.ntypes),
        'num_relations': len(g.etypes),
        'epochs': 100,
        'learning_rate': 0.000001,
        'device': str(device)
    }

    # Move relation embeddings to device
    relation_embeddings = {
        k: v.to(device) for k, v in relation_embeddings.items()
    }

    # Initialiser le modèle
    torch.manual_seed(42)

    model = HGT(
        G=g,
        in_dim=768,
        hidden_dim=768,
        out_dim=384,
        n_layers=2,
        n_heads=12,
        dropout=0.05
    ).to(device)

    # Train HGT with contrastive learning
    print("Training HGT model...")
    model, embeddings = train_hgt(g, node_features, relation_embeddings)

    # Séparer le clustering par type de nœud
    # 1. Clustering des auteurs
    print("\n" + "="*50)
    print("CLUSTERING DES AUTEURS")
    print("="*50)

    if 'author' in embeddings:
        author_embeddings = embeddings['author']
        n_clusters = len(np.unique(true_labels))

        print("\nEvaluating author clustering...")
        nmi, ari, f1, acc, pred_labels = evaluate_clustering(
            author_embeddings,
            true_labels,
            n_clusters,
            node_type='author'
        )

        print(f"\nAuthor Clustering Evaluation:")
        print(f"NMI: {nmi:.4f}")
        print(f"ARI: {ari:.4f}")
        print(f"F1: {f1:.4f}")
        print(f"ACC: {acc:.4f}")

        # Visualize clusters
        print("\nVisualizing author clusters...")
        visualize_clusters(
            author_embeddings,
            true_labels,
            pred_labels,
            "Author Cluster Visualization"
        )

        # Analyze clusters
        print("\nAnalyzing author clusters...")
        purity = analyze_clusters(author_embeddings, true_labels, pred_labels, id_node_map)
        print(f"Author Cluster Purity: {purity:.4f}")

        # Sauvegarder les résultats des auteurs
        results_data['author'] = {
            'num_nodes': len(author_embeddings),
            'n_clusters': n_clusters,
            'nmi': nmi,
            'ari': ari,
            'f1': f1,
            'acc': acc,
            'purity': purity
        }

    # 2. Clustering des publications
    print("\n" + "="*50)
    print("CLUSTERING DES PUBLICATIONS")
    print("="*50)

    if 'publication' in embeddings:
        # Obtenir les vraies étiquettes des publications si disponibles
        pub_true_labels = None
        if hasattr(g.nodes['publication'], 'data') and 'true_domain' in g.nodes['publication'].data:
            pub_true_labels = g.nodes['publication'].data['true_domain'].cpu().numpy()

        # Si les vraies étiquettes ne sont pas disponibles, essayer de les extraire du graphe RDF
        if pub_true_labels is None:
            pub_true_labels = get_node_domains(g, 'publication', id_node_map, rdf_graph)

        if pub_true_labels is not None and len(pub_true_labels) > 0:
            pub_embeddings = embeddings['publication']
            n_pub_clusters = len(np.unique(pub_true_labels))

            # Paramètres spécifiques pour les publications
            print("\nEvaluating publication clustering...")
            pub_nmi, pub_ari, pub_f1, pub_acc, pub_pred_labels = evaluate_clustering(
                pub_embeddings,
                pub_true_labels,
                n_pub_clusters,
                node_type='publication'
            )

            print(f"\nPublication Clustering Evaluation:")
            print(f"NMI: {pub_nmi:.4f}")
            print(f"ARI: {pub_ari:.4f}")
            print(f"F1: {pub_f1:.4f}")
            print(f"ACC: {pub_acc:.4f}")

            # Visualiser avec le même format que pour les auteurs
            visualize_clusters(
                pub_embeddings,
                pub_true_labels,
                pub_pred_labels,
                "Publication Cluster Visualization"
            )

            # Analyser les clusters de publications
            print("\nAnalyzing publication clusters...")
            pub_purity = analyze_clusters(pub_embeddings, pub_true_labels, pub_pred_labels, id_node_map)
            print(f"Publication Cluster Purity: {pub_purity:.4f}")

            # Sauvegarder les résultats des publications
            results_data['publication'] = {
                'num_nodes': len(pub_embeddings),
                'n_clusters': n_pub_clusters,
                'nmi': pub_nmi,
                'ari': pub_ari,
                'f1': pub_f1,
                'acc': pub_acc,
                'purity': pub_purity
            }
        else:
            print("Pas d'étiquettes de domaine disponibles pour les publications.")

    # 3. Clustering des venues
    print("\n" + "="*50)
    print("CLUSTERING DES VENUES")
    print("="*50)

    if 'venue' in embeddings:
        # Obtenir les vraies étiquettes des venues si disponibles
        conf_true_labels = None
        if hasattr(g.nodes['venue'], 'data') and 'true_domain' in g.nodes['venue'].data:
            conf_true_labels = g.nodes['venue'].data['true_domain'].cpu().numpy()

        # Si les vraies étiquettes ne sont pas disponibles, essayer de les extraire du graphe RDF
        if conf_true_labels is None:
            conf_true_labels = get_node_domains(g, 'venue', id_node_map, rdf_graph)

        if conf_true_labels is not None and len(conf_true_labels) > 0:
            conf_embeddings = embeddings['venue']
            n_conf_clusters = len(np.unique(conf_true_labels))

            # Paramètres spécifiques pour les venues
            print("\nEvaluating venue clustering with specialized parameters...")

            # Essayer plusieurs configurations pour les venues
            best_conf_nmi = 0
            best_conf_ari = 0
            best_conf_f1 = 0
            best_conf_acc = 0
            best_conf_pred_labels = None

            # Configuration 1: Plus de composantes PCA
            print("\nTesting configuration 1: More PCA components...")
            conf_nmi1, conf_ari1, conf_f1_1, conf_acc1, conf_pred_labels1 = evaluate_clustering_conference(
                conf_embeddings,
                conf_true_labels,
                n_conf_clusters,
                pca_components=min(48, conf_embeddings.shape[1]),
                n_init_kmeans=30,
                n_runs=30
            )

            if conf_nmi1 > best_conf_nmi:
                best_conf_nmi = conf_nmi1
                best_conf_ari = conf_ari1
                best_conf_f1 = conf_f1_1
                best_conf_acc = conf_acc1
                best_conf_pred_labels = conf_pred_labels1
                print(f"New best configuration (1): NMI={conf_nmi1:.4f}, ARI={conf_ari1:.4f}, F1={conf_f1_1:.4f}, ACC={conf_acc1:.4f}")

            # Configuration 2: Moins de clusters
            print("\nTesting configuration 2: Fewer clusters...")
            conf_nmi2, conf_ari2, conf_f1_2, conf_acc2, conf_pred_labels2 = evaluate_clustering_conference(
                conf_embeddings,
                conf_true_labels,
                max(3, n_conf_clusters-2),  # Réduire le nombre de clusters
                pca_components=min(32, conf_embeddings.shape[1]),
                n_init_kmeans=40,
                n_runs=40
            )

            if conf_nmi2 > best_conf_nmi:
                best_conf_nmi = conf_nmi2
                best_conf_ari = conf_ari2
                best_conf_f1 = conf_f1_2
                best_conf_acc = conf_acc2
                best_conf_pred_labels = conf_pred_labels2
                print(f"New best configuration (2): NMI={conf_nmi2:.4f}, ARI={conf_ari2:.4f}, F1={conf_f1_2:.4f}, ACC={conf_acc2:.4f}")

            # Configuration 3: Utiliser le clustering hiérarchique avec différents nombres de clusters
            print("\nTesting configuration 3: Hierarchical clustering with different parameters...")
            conf_nmi3, conf_ari3, conf_f1_3, conf_acc3, conf_pred_labels3 = evaluate_clustering_dbscan(
                conf_embeddings,
                conf_true_labels
            )

            if conf_nmi3 > best_conf_nmi:
                best_conf_nmi = conf_nmi3
                best_conf_ari = conf_ari3
                best_conf_f1 = conf_f1_3
                best_conf_acc = conf_acc3
                best_conf_pred_labels = conf_pred_labels3
                print(f"New best configuration (3): NMI={conf_nmi3:.4f}, ARI={conf_ari3:.4f}, F1={conf_f1_3:.4f}, ACC={conf_acc3:.4f}")

            print(f"\nBest Venue Clustering Evaluation:")
            print(f"NMI: {best_conf_nmi:.4f}")
            print(f"ARI: {best_conf_ari:.4f}")
            print(f"F1: {best_conf_f1:.4f}")
            print(f"ACC: {best_conf_acc:.4f}")

            # Visualiser avec le même format que pour les auteurs
            visualize_clusters(
                conf_embeddings,
                conf_true_labels,
                best_conf_pred_labels,
                "Venue Cluster Visualization"
            )

            # Analyser les clusters de venues
            print("\nAnalyzing venue clusters...")
            conf_purity = analyze_clusters(conf_embeddings, conf_true_labels, best_conf_pred_labels, id_node_map)
            print(f"Venue Cluster Purity: {conf_purity:.4f}")

            # Sauvegarder les résultats des venues
            results_data['venue'] = {
                'num_nodes': len(conf_embeddings),
                'n_clusters': len(np.unique(conf_true_labels)),
                'nmi': best_conf_nmi,
                'ari': best_conf_ari,
                'f1': best_conf_f1,
                'acc': best_conf_acc,
                'purity': conf_purity,
                'best_method': 'Agglomerative Clustering (Multi-configuration)'
            }
        else:
            print("Pas d'étiquettes de domaine disponibles pour les venues.")

    # Calculer le temps d'exécution
    end_time = time.time()
    execution_time = end_time - start_time
    results_data['execution_time'] = f"{execution_time:.2f} seconds"

    # Estimer l'utilisation mémoire
    if torch.cuda.is_available():
        memory_usage = f"{torch.cuda.max_memory_allocated() / 1024**3:.2f} GB (GPU)"
    else:
        memory_usage = "CPU mode"
    results_data['memory_usage'] = memory_usage

    # Sauvegarder automatiquement le résumé des résultats
    print("\n" + "="*70)
    print("SAVING HIERARCHICAL CLUSTERING RESULTS SUMMARY")
    print("="*70)
    save_clustering_results_summary(results_data, output_dir)

    # Sauvegarder le modèle et les embeddings
    torch.save(model.state_dict(), 'hgt_model.pt')
    with open('embeddings.pkl', 'wb') as f:
        pickle.dump(embeddings, f)

    print("\nModèle et embeddings sauvegardés avec succès!")

    return model, embeddings, pred_labels

def evaluate_clustering_conference(embeddings, true_labels, n_clusters, pca_components=32, n_init_kmeans=30, n_runs=30):
    """
    Fonction spécialisée pour le clustering des venues utilisant uniquement le clustering hiérarchique
    avec alignement amélioré
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité pour améliorer le clustering
    from sklearn.decomposition import PCA
    pca = PCA(n_components=pca_components, random_state=42)
    embeddings_reduced = pca.fit_transform(embeddings)
    print(f"📊 Variance expliquée par PCA (venues): {sum(pca.explained_variance_ratio_):.4f}")

    # Exécuter le clustering hiérarchique avec différentes méthodes de liaison
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_alignment_quality = 0

    print(f"🔄 Testing hierarchical clustering configurations for venues...")

    for linkage in ['ward', 'complete', 'average', 'single']:
        agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
        pred_labels = agg.fit_predict(embeddings_reduced)

        nmi = normalized_mutual_info_score(true_labels, pred_labels)
        ari = adjusted_rand_score(true_labels, pred_labels)

        # Align predicted labels with true labels for F1 and Accuracy calculation
        aligned_labels = align_cluster_labels(true_labels, pred_labels)
        f1 = f1_score(true_labels, aligned_labels, average='weighted')
        acc = accuracy_score(true_labels, aligned_labels)

        # Calculate alignment quality
        alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)
        alignment_quality = calculate_alignment_quality(true_labels, pred_labels, alignment_mapping)

        print(f"   AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}, Alignment={alignment_quality:.4f}")

        # Select best result based on NMI primarily, with alignment quality as secondary criterion
        if nmi > best_nmi or (nmi == best_nmi and alignment_quality > best_alignment_quality):
            best_nmi = nmi
            best_ari = ari
            best_f1 = f1
            best_acc = acc
            best_labels = pred_labels
            best_alignment_quality = alignment_quality

    print(f"✅ Best venue configuration: NMI={best_nmi:.4f}, Alignment Quality={best_alignment_quality:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def evaluate_clustering_dbscan(embeddings, true_labels):
    """
    Utiliser le clustering hiérarchique pour les venues avec différents nombres de clusters
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité
    try:
        from umap import UMAP
        print("Utilisation de UMAP pour la réduction de dimensionnalité...")
        reducer = UMAP(n_components=min(32, embeddings.shape[1]),
                      n_neighbors=min(15, embeddings.shape[0]-1),
                      min_dist=0.1,
                      random_state=42)
        embeddings_reduced = reducer.fit_transform(embeddings)
    except ImportError:
        # Fallback to PCA if UMAP is not available
        from sklearn.decomposition import PCA
        print("UMAP non disponible, utilisation de PCA...")
        pca = PCA(n_components=min(32, embeddings.shape[1]), random_state=42)
        embeddings_reduced = pca.fit_transform(embeddings)

    # Essayer différents nombres de clusters
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_method = None

    # Essayer différents nombres de clusters
    n_clusters_list = [
        len(np.unique(true_labels)),
        len(np.unique(true_labels))-1,
        len(np.unique(true_labels))+1,
        len(np.unique(true_labels))-2,
        len(np.unique(true_labels))+2,
        max(3, len(np.unique(true_labels))//2),
        min(len(embeddings)//10, len(np.unique(true_labels))*2)
    ]

    for n_clusters in n_clusters_list:
        for linkage in ['ward', 'complete', 'average', 'single']:
            agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
            pred_labels = agg.fit_predict(embeddings_reduced)

            nmi = normalized_mutual_info_score(true_labels, pred_labels)
            ari = adjusted_rand_score(true_labels, pred_labels)

            # Align predicted labels with true labels for F1 and Accuracy calculation
            aligned_labels = align_cluster_labels(true_labels, pred_labels)
            f1 = f1_score(true_labels, aligned_labels, average='weighted')
            acc = accuracy_score(true_labels, aligned_labels)

            print(f"AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}")

            if nmi > best_nmi:
                best_nmi = nmi
                best_ari = ari
                best_f1 = f1
                best_acc = acc
                best_labels = pred_labels
                best_method = f"AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage})"

    print(f"\nMeilleure méthode: {best_method}")
    print(f"NMI: {best_nmi:.4f}, ARI: {best_ari:.4f}, F1: {best_f1:.4f}, ACC: {best_acc:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def get_node_domains(g, node_type, id_node_map, rdf_graph):
    """
    Extraire les domaines des nœuds à partir du graphe RDF
    """
    print(f"Extraction des domaines pour les nœuds de type '{node_type}'...")

    # Créer un vocabulaire des catégories
    category_vocab = {}
    for s, p, o in rdf_graph:
        if str(p) == "http://example.org/hasDomain":
            domain_uri = str(o)
            if domain_uri not in category_vocab:
                category_vocab[domain_uri] = len(category_vocab)

    # Initialiser les labels
    num_nodes = g.num_nodes(node_type)
    labels = np.zeros(num_nodes)

    # Pour chaque nœud, trouver son domaine
    for i in range(num_nodes):
        # Obtenir l'URI du nœud
        node_uri = id_node_map[int(g.nodes(node_type)[i])]

        # Chercher le domaine dans le graphe RDF
        for s, p, o in rdf_graph:
            if str(s) == node_uri and str(p) == "http://example.org/hasDomain":
                domain_uri = str(o)
                if domain_uri in category_vocab:
                    labels[i] = category_vocab[domain_uri]
                    break

    # Vérifier si des domaines ont été trouvés
    if np.all(labels == 0) and len(category_vocab) > 0:
        print(f"Aucun domaine trouvé pour les nœuds de type '{node_type}'. Essai avec publishesDomain...")

        # Essayer avec publishesDomain pour les conférences
        for i in range(num_nodes):
            node_uri = id_node_map[int(g.nodes(node_type)[i])]

            for s, p, o in rdf_graph:
                if str(s) == node_uri and str(p) == "http://example.org/publishesDomain":
                    domain_uri = str(o)
                    if domain_uri in category_vocab:
                        labels[i] = category_vocab[domain_uri]
                        break

    # Vérifier si des domaines ont été trouvés
    if np.all(labels == 0) and len(category_vocab) > 0:
        print(f"Aucun domaine trouvé pour les nœuds de type '{node_type}'. Utilisation de l'inférence...")

        # Inférer les domaines à partir des relations
        if node_type == 'venue':
            # Inférer les domaines des venues à partir des publications
            venue_domains = defaultdict(Counter)

            # Parcourir les publications et leurs venues
            for s, p, o in rdf_graph:
                if str(p) == "http://purl.org/dc/elements/1.1/isPartOf":
                    pub_uri = str(s)
                    venue_uri = str(o)

                    # Trouver le domaine de la publication
                    for s2, p2, o2 in rdf_graph:
                        if str(s2) == pub_uri and str(p2) == "http://example.org/hasDomain":
                            domain_uri = str(o2)
                            if domain_uri in category_vocab:
                                venue_domains[venue_uri][domain_uri] += 1

            # Assigner le domaine le plus fréquent à chaque venue
            for i in range(num_nodes):
                venue_uri = id_node_map[int(g.nodes(node_type)[i])]
                if venue_uri in venue_domains and venue_domains[venue_uri]:
                    most_common_domain = venue_domains[venue_uri].most_common(1)[0][0]
                    labels[i] = category_vocab[most_common_domain]

    # Vérifier si des domaines ont été trouvés
    found_domains = np.sum(labels != 0)
    print(f"Domaines trouvés pour {found_domains}/{num_nodes} nœuds de type '{node_type}'")

    if found_domains == 0:
        return None

    return labels

def get_true_labels(g, rdf_graph, id_node_map):
    """
    Get true labels based on research domains using hasDomain relation.

    Args:
        g: DGL graph
        rdf_graph: RDF graph containing domain information
        id_node_map: Mapping from node IDs to URIs

    Returns:
        labels: numpy array of labels for author nodes
        category_vocab: dictionary mapping domain URIs to numeric labels
    """
    # Créer le vocabulaire des domaines
    category_vocab = {}
    category_counter = 0
    for s, p, o in rdf_graph:
        if str(p) == "http://example.org/hasDomain":
            domain_uri = str(o)
            if domain_uri not in category_vocab:
                category_vocab[domain_uri] = category_counter
                category_counter += 1

    # Initialiser les labels pour les nœuds de type 'author'
    num_authors = g.number_of_nodes('author')
    labels = np.zeros(num_authors)

    # Pour chaque auteur, trouver son domaine
    for i in range(num_authors):
        # Obtenir l'URI de l'auteur
        author_uri = id_node_map[int(g.nodes('author')[i])]

        # Chercher le domaine dans le graphe RDF
        for s, p, o in rdf_graph:
            if str(s) == author_uri and str(p) == "http://example.org/hasDomain":
                domain_uri = str(o)
                if domain_uri in category_vocab:
                    labels[i] = category_vocab[domain_uri]
                    break

    return labels, category_vocab

# Add this before the analyze_graph_coverage() function definition
rdf_type_map = {
    "http://xmlns.com/foaf/0.1/Person": "author",
    "http://example.org/Publication": "publication",
    "http://example.org/Domain": "domain",
    "http://example.org/Conference": "conference",
    "http://example.org/Journal": "journal",
    "http://example.org/Venue": "venue"
}

def verify_relation_embeddings_usage(model, relation_embeddings):
    """
    Vérifie que les embeddings de relations sont bien utilisés
    """
    print("\nVérification des embeddings de relations:")
    print(f"Nombre d'embeddings chargés: {len(relation_embeddings)}")
    print("Dimensions des embeddings:")
    for etype, emb in relation_embeddings.items():
        print(f"  {etype}: {emb.shape}")

    # Vérifier que tous les types de relations du modèle ont un embedding
    model_etypes = set(model.G.etypes)
    emb_etypes = set(relation_embeddings.keys())
    missing = model_etypes - emb_etypes
    if missing:
        print(f"⚠️ Types de relations sans embeddings: {missing}")
    else:
        print("✅ Tous les types de relations ont des embeddings")

    # Vérifier les relations utilisées dans le graphe
    used_relations = set()
    for canonical_etype in model.G.canonical_etypes:
        _, etype, _ = canonical_etype
        used_relations.add(etype)
        src, dst = model.G.edges(etype=canonical_etype)
        print(f"  Relation {canonical_etype}: {len(src)} arêtes")

    # Vérifier quels embeddings sont effectivement utilisés
    used_embeddings = used_relations.intersection(emb_etypes)
    print(f"\nEmbeddings de relations effectivement utilisés: {len(used_embeddings)}/{len(emb_etypes)}")
    print(f"Relations utilisées: {sorted(list(used_embeddings))}")

    return used_embeddings

def analyze_graph_coverage():
    """
    Analyse la couverture du graphe RDF
    """
    # Compter tous les triplets
    total_triples = len(rdf_graph)

    # Analyser les types de nœuds
    node_type_counts = defaultdict(int)
    unmapped_types = set()

    for s in rdf_graph.subjects():
        type_found = False
        for p, o in rdf_graph.predicate_objects(subject=s):
            if 'type' in str(p).lower():
                type_uri = str(o)
                if type_uri in rdf_type_map:
                    node_type_counts[rdf_type_map[type_uri]] += 1
                    type_found = True
                else:
                    unmapped_types.add(type_uri)
        if not type_found:
            node_type_counts['unknown'] += 1

    # Analyser les relations
    relation_counts = defaultdict(int)
    unmapped_relations = set()

    for s, p, o in rdf_graph:
        if isinstance(s, URIRef) and isinstance(o, URIRef):
            pred = str(p)
            if "rdf-syntax-ns#type" not in pred:
                relation_counts[pred.split("/")[-1]] += 1

def cluster_publications_by_domain(g, embeddings, id_node_map):
    """
    Cluster publications and analyze their distribution across domains.
    """
    # Extraire les embeddings des publications et domaines
    pub_embeddings = embeddings['publication']
    domain_embeddings = embeddings['domain']

    # Normaliser les embeddings
    pub_embeddings = F.normalize(pub_embeddings, p=2, dim=1)
    domain_embeddings = F.normalize(domain_embeddings, p=2, dim=1)

    # Calculer la similarité entre publications et domaines
    similarity = torch.mm(pub_embeddings, domain_embeddings.t())

    # Assigner chaque publication au domaine le plus similaire
    _, domain_assignments = torch.max(similarity, dim=1)
    domain_assignments = domain_assignments.cpu().numpy()

    # Analyser les résultats
    print(f"Nombre de publications: {len(pub_embeddings)}")
    print(f"Nombre de domaines: {len(domain_embeddings)}")

    # Compter les publications par domaine
    domain_counts = Counter(domain_assignments)
    for domain_id, count in domain_counts.items():
        # Obtenir l'URI du domaine
        domain_node_id = g.nodes('domain')[domain_id]
        domain_uri = id_node_map[int(domain_node_id)]
        domain_name = domain_uri.split('/')[-1]
        print(f"Domaine {domain_name}: {count} publications")

    # Visualiser la distribution
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(domain_counts)), [count for _, count in sorted(domain_counts.items())])
    plt.xlabel('Domaine ID')
    plt.ylabel('Nombre de publications')
    plt.title('Distribution des publications par domaine')

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'publication_domain_distribution.png')
    plt.savefig(filepath, dpi=300)
    plt.close()

    return domain_assignments

def cluster_conferences_by_domain(g, embeddings, id_node_map):
    """
    Cluster venues and analyze their distribution across domains.
    """
    # Extraire les embeddings des venues et domaines
    conf_embeddings = embeddings['venue']
    domain_embeddings = embeddings['domain']

    # Normaliser les embeddings
    conf_embeddings = F.normalize(conf_embeddings, p=2, dim=1)
    domain_embeddings = F.normalize(domain_embeddings, p=2, dim=1)

    # Calculer la similarité entre venues et domaines
    similarity = torch.mm(conf_embeddings, domain_embeddings.t())

    # Assigner chaque venue au domaine le plus similaire
    _, domain_assignments = torch.max(similarity, dim=1)
    domain_assignments = domain_assignments.cpu().numpy()

    # Analyser les résultats
    print(f"Nombre de venues: {len(conf_embeddings)}")
    print(f"Nombre de domaines: {len(domain_embeddings)}")

    # Compter les venues par domaine
    domain_counts = Counter(domain_assignments)
    for domain_id, count in domain_counts.items():
        # Obtenir l'URI du domaine
        domain_node_id = g.nodes('domain')[domain_id]
        domain_uri = id_node_map[int(domain_node_id)]
        domain_name = domain_uri.split('/')[-1]
        print(f"Domaine {domain_name}: {count} venues")

    # Visualiser la distribution et la matrice de similarité
    plt.figure(figsize=(12, 10))

    # Distribution des venues par domaine
    plt.subplot(2, 1, 1)
    plt.bar(range(len(domain_counts)), [count for _, count in sorted(domain_counts.items())])
    plt.xlabel('Domaine ID')
    plt.ylabel('Nombre de venues')
    plt.title('Distribution des venues par domaine')

    # Heatmap de similarité entre venues et domaines
    plt.subplot(2, 1, 2)
    plt.imshow(similarity.cpu().numpy(), cmap='viridis', aspect='auto')
    plt.colorbar(label='Similarité cosinus')
    plt.xlabel('Domaines')
    plt.ylabel('Venues')
    plt.title('Similarité entre venues et domaines')

    plt.tight_layout()

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'venue_domain_analysis.png')
    plt.savefig(filepath, dpi=300)
    plt.close()

    return domain_assignments

if __name__ == "__main__":
    print("Démarrage du pipeline de clustering HGT...")

    # Chargement du graphe RDF
    rdf_graph = Graph()
    rdf_graph.parse("DBLP_petit.rdf")

    # Ajouter l'analyse de couverture
    analyze_graph_coverage()

    # Chargement des embeddings
    with open("node_features.pkl", "rb") as f:
        node_features = pickle.load(f)

    with open("relation_embeddings.pkl", "rb") as f:
        relation_embeddings = pickle.load(f)

    # === Détecter les types RDF de chaque entité
    # === Mapping explicite des types RDF vers noms clairs
    rdf_type_map = {
        "http://xmlns.com/foaf/0.1/Person": "author",
        "http://example.org/Publication": "publication",
        "http://example.org/Domain": "domain",
        "http://example.org/Conference": "conference",
        "http://example.org/Journal": "journal",
        "http://example.org/Venue": "venue"
    }

    # === Détection des types RDF de chaque entité avec mapping
    node_types = {}
    for s in rdf_graph.subjects():
        for p, o in rdf_graph.predicate_objects(subject=s):
            if 'type' in str(p).lower():
                mapped = rdf_type_map.get(str(o))
                if mapped:
                    node_types[str(s)] = mapped
                break  # stop at first type match

    # === Regrouper les arêtes par type de relation hétérogène
    edge_dict = defaultdict(lambda: ([], []))  # key: (src_type, relation, dst_type)
    # === Mapping explicite des classes RDF utilisées dans subClassOf
    class_uri_to_type = {
        "http://example.org/Conference": "conference",
        "http://example.org/Journal": "journal",
        "http://example.org/Venue": "venue"
    }
    # Filtrer uniquement les triplets URIRef -> URIRef
    for s, p, o in rdf_graph:
        if isinstance(s, URIRef) and isinstance(o, URIRef):
            # === Ignorer les relations rdf:type
            if "rdf-syntax-ns#type" in str(p):
                continue

            s_uri, p_uri, o_uri = str(s), str(p), str(o)

            # === Cas spécial : subClassOf → corriger les types
            if p_uri.endswith("subClassOf"):
                s_type = class_uri_to_type.get(s_uri, "venue")
                o_type = class_uri_to_type.get(o_uri, "venue")
                rel = "subClassOf"
                edge_dict[(s_type, rel, o_type)][0].append(s_uri)
                edge_dict[(s_type, rel, o_type)][1].append(o_uri)
                continue  # ne pas traiter ce triplet plus loin

            s_uri, p_uri, o_uri = str(s), str(p), str(o)
            s_type = node_types.get(s_uri, "venue")
            o_type = node_types.get(o_uri, "venue")
            rel = p_uri.split("/")[-1]  # ex: creator, isPartOf
            edge_dict[(s_type, rel, o_type)][0].append(s_uri)
            edge_dict[(s_type, rel, o_type)][1].append(o_uri)

    # === Créer un mapping global des identifiants de nœuds
    all_node_ids = set()
    for (srcs, dsts) in edge_dict.values():
        all_node_ids.update(srcs)
        all_node_ids.update(dsts)

    node_id_map = {uri: idx for idx, uri in enumerate(sorted(all_node_ids))}
    id_node_map = {v: k for k, v in node_id_map.items()}

    # === Construction du dictionnaire final pour DGL
    data_dict = {}
    for (srctype, reltype, dsttype), (srcs, dsts) in edge_dict.items():
        src_idx = [node_id_map[s] for s in srcs]
        dst_idx = [node_id_map[d] for d in dsts]
        data_dict[(srctype, reltype, dsttype)] = (src_idx, dst_idx)

    # === Création du graphe hétérogène DGL
    g = dgl.heterograph(data_dict)

    # === Ajout des features des nœuds (si disponibles)
    features = torch.zeros((len(node_id_map), 768))
    for uri, idx in node_id_map.items():
        if uri in node_features:
            features[idx] = node_features[uri]
    from collections import defaultdict

    # Étape 1 : regrouper les indices par type de nœud
    node_type_map = defaultdict(list)
    for uri, idx in node_id_map.items():
        ntype = node_types.get(uri, "venue").lower()
        node_type_map[ntype].append(idx)

    # Étape 2 : assigner les features par type de nœud
    from collections import defaultdict
    ndata_feats = {}
    for ntype in g.ntypes:
        nids = g.nodes(ntype)
        feats = []

        for nid in nids:
            uri = id_node_map[int(nid)]
            feat = node_features.get(uri, torch.zeros(768))
            feats.append(feat)

        ndata_feats[ntype] = torch.stack(feats)

    # Étape 2 : assigner les features par type de nœud
    g.ndata['feat'] = ndata_feats

    print(f"✅ Graphe DGL hétérogène construit avec {g.num_nodes()} nœuds et {g.num_edges()} arêtes.")
    print(f"Types de relations : {list(g.canonical_etypes)}")

    # Obtention des labels vrais basés sur hasDomain
    true_labels, domain_vocab = get_true_labels(g, rdf_graph, id_node_map)
    print(f"Nombre de classes (domaines) : {len(domain_vocab)}")
    print(f"Distribution des labels : {Counter(true_labels)}")

    # Pour voir la correspondance domaines-labels
    for domain, label in domain_vocab.items():
        print(f"Domaine: {domain.split('/')[-1]}, Label: {label}")

    # Préparation des embeddings de relations pour HGT
    print("\nChargement des embeddings de relations...")
    print(f"Clés disponibles dans relation_embeddings: {list(relation_embeddings.keys())}")

    # Mapping entre les noms courts utilisés dans le graphe et les URIs complètes
    relation_uri_map = {
        'creator': 'http://purl.org/dc/elements/1.1/creator',
        'subClassOf': 'http://www.w3.org/2000/01/rdf-schema#subClassOf',
        'domain_dominant': 'http://example.org/features/domain_dominant',
        'hasDomain': 'http://example.org/hasDomain',
        'publishesDomain': 'http://example.org/publishesDomain',
        'isPartOf': 'http://purl.org/dc/elements/1.1/isPartOf',
        'hasPublishedIn': 'http://example.org/hasPublishedIn'
    }

    hgt_relation_embeddings = {}
    for etype in g.etypes:
        if etype in relation_uri_map and relation_uri_map[etype] in relation_embeddings:
            hgt_relation_embeddings[etype] = relation_embeddings[relation_uri_map[etype]]
            print(f"✅ Found embedding for relation type '{etype}'")
        else:
            print(f"⚠️ No embedding found for relation type '{etype}'")
            # Créer un embedding basé sur le nom de la relation
            # Utiliser un modèle de texte simple pour encoder le nom
            from sentence_transformers import SentenceTransformer
            text_model = SentenceTransformer('all-MiniLM-L6-v2')
            embedding = text_model.encode(etype, convert_to_tensor=True)
            if embedding.shape[0] != 768:
                embedding = torch.nn.functional.pad(embedding, (0, 768 - embedding.shape[0]))
            hgt_relation_embeddings[etype] = embedding
            print(f"  Created embedding for '{etype}' based on its name")

    # Exécution du pipeline de clustering
    print("\nDémarrage du clustering...")
    model, embeddings, pred_labels = run_hgt_clustering(
        g, node_features, hgt_relation_embeddings, true_labels, id_node_map
    )

    # Vérification des embeddings de relations
    verify_relation_embeddings_usage(model, hgt_relation_embeddings)
# Out:
# Démarrage du pipeline de clustering HGT...
# ✅ Graphe DGL hétérogène construit avec 5292 nœuds et 5202 arêtes.
# Types de relations : [('author', 'domain_dominant', 'domain'), ('author', 'hasDomain', 'domain'), ('author', 'hasPublishedIn', 'venue'), ('publication', 'creator', 'author'), ('publication', 'isPartOf', 'venue'), ('venue', 'publishesDomain', 'domain')]
# Nombre de classes (domaines) : 11
# Distribution des labels : Counter({0.0: 195, 5.0: 147, 2.0: 139, 9.0: 119, 3.0: 117, 4.0: 98, 10.0: 96, 7.0: 94, 1.0: 63, 6.0: 56, 8.0: 41})
# Domaine: nlp, Label: 0
# Domaine: knowledgegraphs, Label: 1
# Domaine: databases, Label: 2
# Domaine: softwareengineering, Label: 3
# Domaine: computervision, Label: 4
# Domaine: informationretrieval, Label: 5
# Domaine: deeplearning, Label: 6
# Domaine: bioinformatics, Label: 7
# Domaine: artificialintelligence, Label: 8
# Domaine: datamining, Label: 9
# Domaine: machinelearning, Label: 10
#
# Chargement des embeddings de relations...
# Clés disponibles dans relation_embeddings: ['http://example.org/hasPublishedIn', 'http://www.w3.org/2000/01/rdf-schema#subClassOf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://purl.org/dc/elements/1.1/creator', 'http://purl.org/dc/elements/1.1/isPartOf', 'http://example.org/hasDomain', 'http://example.org/features/domain_dominant', 'http://example.org/publishesDomain']
# ✅ Found embedding for relation type 'domain_dominant'
# ✅ Found embedding for relation type 'hasDomain'
# ✅ Found embedding for relation type 'hasPublishedIn'
# ✅ Found embedding for relation type 'creator'
# ✅ Found embedding for relation type 'isPartOf'
# ✅ Found embedding for relation type 'publishesDomain'
#
# Démarrage du clustering...
# Training HGT model...
# Training on cpu for 100 epochs...
# Epoch 10/100, Loss: 7.6505
# Learning rate: 0.000005
# Epoch 20/100, Loss: 7.5325
# Learning rate: 0.000005
# Epoch 30/100, Loss: 7.3667
# Learning rate: 0.000004
# Epoch 40/100, Loss: 7.1359
# Learning rate: 0.000003
# Epoch 50/100, Loss: 7.0618
# Learning rate: 0.000003
# Epoch 60/100, Loss: 6.9547
# Learning rate: 0.000002
# Epoch 70/100, Loss: 6.8484
# Learning rate: 0.000001
# Epoch 80/100, Loss: 6.8002
# Learning rate: 0.000000
# Epoch 90/100, Loss: 6.7733
# Learning rate: 0.000000
# Epoch 100/100, Loss: 6.7819
# Learning rate: 0.000000
#
# ==================================================
# CLUSTERING DES AUTEURS
# ==================================================
#
# Evaluating author clustering...
# 📊 Variance expliquée par PCA (author): 0.9206
# 🔄 Testing hierarchical clustering with different linkage methods for author...
#    AgglomerativeClustering (linkage=ward): NMI=0.9014, ARI=0.8688, F1=0.9205, ACC=0.9099, Alignment=0.9099
#    AgglomerativeClustering (linkage=complete): NMI=0.9140, ARI=0.8707, F1=0.9421, ACC=0.9339, Alignment=0.9339
#    AgglomerativeClustering (linkage=average): NMI=0.8899, ARI=0.8366, F1=0.9209, ACC=0.9107, Alignment=0.9107
#    AgglomerativeClustering (linkage=single): NMI=0.8866, ARI=0.8222, F1=0.8693, ACC=0.8567, Alignment=0.8567
# ✅ Best author clustering: NMI=0.9140, Alignment Quality=0.9339
#
# Author Clustering Evaluation:
# NMI: 0.9140
# ARI: 0.8707
# F1: 0.9421
# ACC: 0.9339
#
# Visualizing author clusters...
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Author Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 11
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 6: 55 nodes (Precision: 45.1%, Recall: 98.2%)
#    Cluster 1 ↔ Domain 10: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 2 ↔ Domain 2: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 3 ↔ Domain 5: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 4 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 5 ↔ Domain 9: 119 nodes (Precision: 94.4%, Recall: 100.0%)
#    Cluster 6 ↔ Domain 0: 167 nodes (Precision: 100.0%, Recall: 85.6%)
#    Cluster 7 ↔ Domain 7: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 8 ↔ Domain 1: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 9 ↔ Domain 8: 41 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 10 ↔ Domain 4: 98 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1088/1165 (93.4%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\author_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing author clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 122
# Dominant label: 6.0 (55 nodes, 45.1%)
# True label distribution:
#   Label 0.0: 25 nodes (20.5%)
#   Label 2.0: 8 nodes (6.6%)
#   Label 5.0: 11 nodes (9.0%)
#   Label 6.0: 55 nodes (45.1%)
#   Label 7.0: 23 nodes (18.9%)
#
# Cluster 1:
# Number of nodes: 94
# Dominant label: 10.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 0.0: 1 nodes (1.1%)
#   Label 10.0: 93 nodes (98.9%)
#
# Cluster 2:
# Number of nodes: 128
# Dominant label: 2.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 2.0: 128 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 138
# Dominant label: 5.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 0.0: 2 nodes (1.4%)
#   Label 5.0: 136 nodes (98.6%)
#
# Cluster 4:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 126
# Dominant label: 9.0 (119 nodes, 94.4%)
# True label distribution:
#   Label 2.0: 3 nodes (2.4%)
#   Label 6.0: 1 nodes (0.8%)
#   Label 9.0: 119 nodes (94.4%)
#   Label 10.0: 3 nodes (2.4%)
#
# Cluster 6:
# Number of nodes: 167
# Dominant label: 0.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 167 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 71
# Dominant label: 7.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 7.0: 71 nodes (100.0%)
#
# Cluster 8:
# Number of nodes: 63
# Dominant label: 1.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 63 nodes (100.0%)
#
# Cluster 9:
# Number of nodes: 41
# Dominant label: 8.0 (41 nodes, 100.0%)
# True label distribution:
#   Label 8.0: 41 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 98
# Dominant label: 4.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 98 nodes (100.0%)
#
# Overall cluster purity: 0.9339
# Author Cluster Purity: 0.9339
#
# ==================================================
# CLUSTERING DES PUBLICATIONS
# ==================================================
# Extraction des domaines pour les nœuds de type 'publication'...
# Domaines trouvés pour 970/1443 nœuds de type 'publication'
#
# Evaluating publication clustering...
# 📊 Variance expliquée par PCA (publication): 0.8964
# 🔄 Testing hierarchical clustering with different linkage methods for publication...
#    AgglomerativeClustering (linkage=ward): NMI=0.8378, ARI=0.6304, F1=0.8208, ACC=0.7789, Alignment=0.7789
#    AgglomerativeClustering (linkage=complete): NMI=0.1546, ARI=-0.0947, F1=0.0898, ACC=0.1587, Alignment=0.1587
#    AgglomerativeClustering (linkage=average): NMI=0.1562, ARI=-0.0922, F1=0.0898, ACC=0.1587, Alignment=0.1587
#    AgglomerativeClustering (linkage=single): NMI=0.1725, ARI=-0.0351, F1=0.2392, ACC=0.2640, Alignment=0.2640
# ✅ Best publication clustering: NMI=0.8378, Alignment Quality=0.7789
#
# Publication Clustering Evaluation:
# NMI: 0.8378
# ARI: 0.6304
# F1: 0.8208
# ACC: 0.7789
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Publication Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 11
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 0: 244 nodes (Precision: 100.0%, Recall: 51.6%)
#    Cluster 1 ↔ Domain 6: 55 nodes (Precision: 29.6%, Recall: 98.2%)
#    Cluster 2 ↔ Domain 8: 0 nodes (Precision: 0.0%, Recall: 0.0%)
#    Cluster 3 ↔ Domain 9: 119 nodes (Precision: 86.9%, Recall: 100.0%)
#    Cluster 4 ↔ Domain 2: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 5 ↔ Domain 5: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 6 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 7 ↔ Domain 10: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 8 ↔ Domain 4: 98 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 9 ↔ Domain 7: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 10 ↔ Domain 1: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1124/1443 (77.9%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\publication_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing publication clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 244
# Dominant label: 0.0 (244 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 244 nodes (100.0%)
#
# Cluster 1:
# Number of nodes: 186
# Dominant label: 6.0 (55 nodes, 29.6%)
# True label distribution:
#   Label 0.0: 48 nodes (25.8%)
#   Label 2.0: 8 nodes (4.3%)
#   Label 5.0: 11 nodes (5.9%)
#   Label 6.0: 55 nodes (29.6%)
#   Label 7.0: 23 nodes (12.4%)
#   Label 8.0: 41 nodes (22.0%)
#
# Cluster 2:
# Number of nodes: 167
# Dominant label: 0.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 167 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 137
# Dominant label: 9.0 (119 nodes, 86.9%)
# True label distribution:
#   Label 0.0: 11 nodes (8.0%)
#   Label 2.0: 3 nodes (2.2%)
#   Label 6.0: 1 nodes (0.7%)
#   Label 9.0: 119 nodes (86.9%)
#   Label 10.0: 3 nodes (2.2%)
#
# Cluster 4:
# Number of nodes: 128
# Dominant label: 2.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 2.0: 128 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 138
# Dominant label: 5.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 0.0: 2 nodes (1.4%)
#   Label 5.0: 136 nodes (98.6%)
#
# Cluster 6:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 94
# Dominant label: 10.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 0.0: 1 nodes (1.1%)
#   Label 10.0: 93 nodes (98.9%)
#
# Cluster 8:
# Number of nodes: 98
# Dominant label: 4.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 98 nodes (100.0%)
#
# Cluster 9:
# Number of nodes: 71
# Dominant label: 7.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 7.0: 71 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 63
# Dominant label: 1.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 63 nodes (100.0%)
#
# Overall cluster purity: 0.8947
# Publication Cluster Purity: 0.8947
#
# ==================================================
# CLUSTERING DES VENUES
# ==================================================
# Extraction des domaines pour les nœuds de type 'venue'...
# Domaines trouvés pour 970/1508 nœuds de type 'venue'
#
# Evaluating venue clustering with specialized parameters...
#
# Testing configuration 1: More PCA components...
# 📊 Variance expliquée par PCA (venues): 0.9082
# 🔄 Testing hierarchical clustering configurations for venues...
#    AgglomerativeClustering (n_clusters=11, linkage=ward): NMI=0.7559, ARI=0.4252, F1=0.6569, ACC=0.6313, Alignment=0.6313
#    AgglomerativeClustering (n_clusters=11, linkage=complete): NMI=0.1362, ARI=-0.1110, F1=0.1164, ACC=0.1950, Alignment=0.1950
#    AgglomerativeClustering (n_clusters=11, linkage=average): NMI=0.1400, ARI=-0.1019, F1=0.1164, ACC=0.1950, Alignment=0.1950
#    AgglomerativeClustering (n_clusters=11, linkage=single): NMI=0.1528, ARI=-0.0553, F1=0.2366, ACC=0.2527, Alignment=0.2527
# ✅ Best venue configuration: NMI=0.7559, Alignment Quality=0.6313
# New best configuration (1): NMI=0.7559, ARI=0.4252, F1=0.6569, ACC=0.6313
#
# Testing configuration 2: Fewer clusters...
# 📊 Variance expliquée par PCA (venues): 0.8682
# 🔄 Testing hierarchical clustering configurations for venues...
#    AgglomerativeClustering (n_clusters=9, linkage=ward): NMI=0.7309, ARI=0.4279, F1=0.6420, ACC=0.6200, Alignment=0.6200
#    AgglomerativeClustering (n_clusters=9, linkage=complete): NMI=0.1390, ARI=-0.1059, F1=0.1164, ACC=0.1950, Alignment=0.1950
#    AgglomerativeClustering (n_clusters=9, linkage=average): NMI=0.1797, ARI=-0.1070, F1=0.1575, ACC=0.1817, Alignment=0.1817
#    AgglomerativeClustering (n_clusters=9, linkage=single): NMI=0.1531, ARI=-0.0547, F1=0.2372, ACC=0.2533, Alignment=0.2533
# ✅ Best venue configuration: NMI=0.7309, Alignment Quality=0.6200
#
# Testing configuration 3: Hierarchical clustering with different parameters...
# UMAP non disponible, utilisation de PCA...
# AgglomerativeClustering (n_clusters=11, linkage=ward): NMI=0.7912, ARI=0.5276, F1=0.7528, ACC=0.7089
# AgglomerativeClustering (n_clusters=11, linkage=complete): NMI=0.1363, ARI=-0.1108, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=11, linkage=average): NMI=0.1770, ARI=-0.1137, F1=0.1341, ACC=0.1645
# AgglomerativeClustering (n_clusters=11, linkage=single): NMI=0.1526, ARI=-0.0558, F1=0.2359, ACC=0.2520
# AgglomerativeClustering (n_clusters=10, linkage=ward): NMI=0.7756, ARI=0.4963, F1=0.7105, ACC=0.6824
# AgglomerativeClustering (n_clusters=10, linkage=complete): NMI=0.1372, ARI=-0.1099, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=10, linkage=average): NMI=0.1796, ARI=-0.1070, F1=0.1575, ACC=0.1817
# AgglomerativeClustering (n_clusters=10, linkage=single): NMI=0.1529, ARI=-0.0553, F1=0.2366, ACC=0.2527
# AgglomerativeClustering (n_clusters=12, linkage=ward): NMI=0.7747, ARI=0.4709, F1=0.7083, ACC=0.6658
# AgglomerativeClustering (n_clusters=12, linkage=complete): NMI=0.1358, ARI=-0.1112, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=12, linkage=average): NMI=0.1763, ARI=-0.1143, F1=0.1341, ACC=0.1645
# AgglomerativeClustering (n_clusters=12, linkage=single): NMI=0.1526, ARI=-0.0558, F1=0.2359, ACC=0.2520
# AgglomerativeClustering (n_clusters=9, linkage=ward): NMI=0.7309, ARI=0.4279, F1=0.6420, ACC=0.6200
# AgglomerativeClustering (n_clusters=9, linkage=complete): NMI=0.1390, ARI=-0.1059, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=9, linkage=average): NMI=0.1797, ARI=-0.1070, F1=0.1575, ACC=0.1817
# AgglomerativeClustering (n_clusters=9, linkage=single): NMI=0.1531, ARI=-0.0547, F1=0.2372, ACC=0.2533
# AgglomerativeClustering (n_clusters=13, linkage=ward): NMI=0.7997, ARI=0.5004, F1=0.7500, ACC=0.7023
# AgglomerativeClustering (n_clusters=13, linkage=complete): NMI=0.1350, ARI=-0.1122, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=13, linkage=average): NMI=0.1756, ARI=-0.1147, F1=0.1341, ACC=0.1645
# AgglomerativeClustering (n_clusters=13, linkage=single): NMI=0.1523, ARI=-0.0563, F1=0.2353, ACC=0.2513
# AgglomerativeClustering (n_clusters=5, linkage=ward): NMI=0.5110, ARI=0.1587, F1=0.4010, ACC=0.4231
# AgglomerativeClustering (n_clusters=5, linkage=complete): NMI=0.1443, ARI=-0.0958, F1=0.1164, ACC=0.1950
# AgglomerativeClustering (n_clusters=5, linkage=average): NMI=0.1878, ARI=-0.0830, F1=0.2089, ACC=0.2248
# AgglomerativeClustering (n_clusters=5, linkage=single): NMI=0.1544, ARI=-0.0520, F1=0.2404, ACC=0.2566
# AgglomerativeClustering (n_clusters=22, linkage=ward): NMI=0.7743, ARI=0.4415, F1=0.7755, ACC=0.7036
# AgglomerativeClustering (n_clusters=22, linkage=complete): NMI=0.1667, ARI=-0.1271, F1=0.0944, ACC=0.1525
# AgglomerativeClustering (n_clusters=22, linkage=average): NMI=0.1685, ARI=-0.1251, F1=0.0944, ACC=0.1525
# AgglomerativeClustering (n_clusters=22, linkage=single): NMI=0.1499, ARI=-0.0615, F1=0.2287, ACC=0.2447
#
# Meilleure méthode: AgglomerativeClustering (n_clusters=13, linkage=ward)
# NMI: 0.7997, ARI: 0.5004, F1: 0.7500, ACC: 0.7023
# New best configuration (3): NMI=0.7997, ARI=0.5004, F1=0.7500, ACC=0.7023
#
# Best Venue Clustering Evaluation:
# NMI: 0.7997
# ARI: 0.5004
# F1: 0.7500
# ACC: 0.7023
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_10504\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Venue Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 13
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 6: 55 nodes (Precision: 29.4%, Recall: 98.2%)
#    Cluster 1 ↔ Domain 0: 179 nodes (Precision: 100.0%, Recall: 33.3%)
#    Cluster 2 ↔ Domain 8: 0 nodes (Precision: 0.0%, Recall: 0.0%)
#    Cluster 4 ↔ Domain 2: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 5 ↔ Domain 9: 119 nodes (Precision: 86.9%, Recall: 100.0%)
#    Cluster 6 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 8 ↔ Domain 10: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 9 ↔ Domain 4: 98 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 10 ↔ Domain 7: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 11 ↔ Domain 5: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 12 ↔ Domain 1: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1059/1508 (70.2%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\venue_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing venue clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 187
# Dominant label: 6.0 (55 nodes, 29.4%)
# True label distribution:
#   Label 0.0: 49 nodes (26.2%)
#   Label 2.0: 8 nodes (4.3%)
#   Label 5.0: 11 nodes (5.9%)
#   Label 6.0: 55 nodes (29.4%)
#   Label 7.0: 23 nodes (12.3%)
#   Label 8.0: 41 nodes (21.9%)
#
# Cluster 1:
# Number of nodes: 179
# Dominant label: 0.0 (179 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 179 nodes (100.0%)
#
# Cluster 2:
# Number of nodes: 65
# Dominant label: 0.0 (65 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 65 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 167
# Dominant label: 0.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 167 nodes (100.0%)
#
# Cluster 4:
# Number of nodes: 128
# Dominant label: 2.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 2.0: 128 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 137
# Dominant label: 9.0 (119 nodes, 86.9%)
# True label distribution:
#   Label 0.0: 11 nodes (8.0%)
#   Label 2.0: 3 nodes (2.2%)
#   Label 6.0: 1 nodes (0.7%)
#   Label 9.0: 119 nodes (86.9%)
#   Label 10.0: 3 nodes (2.2%)
#
# Cluster 6:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 64
# Dominant label: 0.0 (64 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 64 nodes (100.0%)
#
# Cluster 8:
# Number of nodes: 94
# Dominant label: 10.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 0.0: 1 nodes (1.1%)
#   Label 10.0: 93 nodes (98.9%)
#
# Cluster 9:
# Number of nodes: 98
# Dominant label: 4.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 98 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 71
# Dominant label: 7.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 7.0: 71 nodes (100.0%)
#
# Cluster 11:
# Number of nodes: 138
# Dominant label: 5.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 0.0: 2 nodes (1.4%)
#   Label 5.0: 136 nodes (98.6%)
#
# Cluster 12:
# Number of nodes: 63
# Dominant label: 1.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 63 nodes (100.0%)
#
# Overall cluster purity: 0.8985
# Venue Cluster Purity: 0.8985
#
# ======================================================================
# SAVING HIERARCHICAL CLUSTERING RESULTS SUMMARY
# ======================================================================
#
# ✅ Clustering results summary saved to: hierarchique hgt par type\clustering_results_summary.txt
#
# Modèle et embeddings sauvegardés avec succès!
#
# Vérification des embeddings de relations:
# Nombre d'embeddings chargés: 6
# Dimensions des embeddings:
#   domain_dominant: torch.Size([768])
#   hasDomain: torch.Size([768])
#   hasPublishedIn: torch.Size([768])
#   creator: torch.Size([768])
#   isPartOf: torch.Size([768])
#   publishesDomain: torch.Size([768])
# ✅ Tous les types de relations ont des embeddings
#   Relation ('author', 'domain_dominant', 'domain'): 1165 arêtes
#   Relation ('author', 'hasDomain', 'domain'): 1165 arêtes
#   Relation ('author', 'hasPublishedIn', 'venue'): 1199 arêtes
#   Relation ('publication', 'creator', 'author'): 1340 arêtes
#   Relation ('publication', 'isPartOf', 'venue'): 267 arêtes
#   Relation ('venue', 'publishesDomain', 'domain'): 66 arêtes
#
# Embeddings de relations effectivement utilisés: 6/6
# Relations utilisées: ['creator', 'domain_dominant', 'hasDomain', 'hasPublishedIn', 'isPartOf', 'publishesDomain']

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from collections import Counter
import numpy as np
import time
import pickle
import random  # Ajout de l'import manquant
from sklearn.cluster import KMeans
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import dgl
from dgl.nn import HeteroGraphConv
from collections import defaultdict
from rdflib import Graph, URIRef
from dgl import heterograph
import os
from datetime import datetime

# Créer le répertoire pour sauvegarder les images
output_dir = "hierarchique hgt par type"
os.makedirs(output_dir, exist_ok=True)
class HGTLayer(nn.Module):
    def __init__(self, in_dim, out_dim, ntypes, etypes, n_heads=4, dropout=0.2):
        super().__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.ntypes = ntypes
        self.etypes = etypes
        self.n_heads = n_heads
        # Ensure out_dim is divisible by n_heads
        self.d_k = out_dim // n_heads
        self.out_dim = self.d_k * n_heads  # Adjust out_dim to be divisible by n_heads
        self.dropout = dropout

        # Linear transformations for each node type
        self.k_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.q_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.v_linears = nn.ModuleDict({
            ntype: nn.Linear(in_dim, self.out_dim) for ntype in ntypes
        })
        self.out_linears = nn.ModuleDict({
            ntype: nn.Linear(self.out_dim, self.out_dim) for ntype in ntypes
        })

        # Ajout des projections pour les embeddings de relations
        self.relation_proj = nn.ModuleDict({
            etype: nn.Linear(768, out_dim) for etype in etypes
        })

    def forward(self, G, h, relation_embeddings):
        with G.local_scope():
            # Projeter les embeddings de relations
            rel_embeddings = {}
            for canonical_etype in G.canonical_etypes:
                src_type, etype, dst_type = canonical_etype
                if etype in self.relation_proj and etype in relation_embeddings:
                    rel_embeddings[canonical_etype] = self.relation_proj[etype](relation_embeddings[etype])

            feat_dict = {}

            for ntype in G.ntypes:
                if G.number_of_nodes(ntype) == 0:
                    continue

                # Initialize output features
                feat_dict[ntype] = torch.zeros((G.number_of_nodes(ntype), self.out_dim),
                                            device=h[ntype].device)

                # Process each relation type
                for canonical_etype in G.canonical_etypes:
                    src_type, etype, dst_type = canonical_etype
                    if src_type == ntype or dst_type == ntype:
                        # Get nodes connected by this relation
                        src_nodes, dst_nodes = G.edges(etype=canonical_etype)

                        if len(src_nodes) == 0 or len(dst_nodes) == 0:
                            continue

                        # Get features
                        q = self.q_linears[dst_type](h[dst_type])
                        k = self.k_linears[src_type](h[src_type])
                        v = self.v_linears[src_type](h[src_type])

                        # Reshape for multi-head attention
                        batch_size = q.size(0)
                        q = q.view(batch_size, self.n_heads, self.d_k)
                        k = k.view(k.size(0), self.n_heads, self.d_k)
                        v = v.view(v.size(0), self.n_heads, self.d_k)

                        # Get features for connected nodes only
                        q = torch.index_select(q, 0, dst_nodes)
                        k = torch.index_select(k, 0, src_nodes)
                        v = torch.index_select(v, 0, src_nodes)

                        # Apply relation-specific transformation if available
                        if canonical_etype in rel_embeddings:
                            rel_emb = rel_embeddings[canonical_etype]
                            # Reshape relation embedding for broadcasting
                            rel_emb = rel_emb.view(1, self.n_heads, self.d_k)

                            # Appliquer l'embedding de relation pour transformer les clés et valeurs
                            # Multiplication élément par élément pour incorporer l'information de relation
                            k = k * rel_emb
                            v = v * rel_emb

                        # Compute attention scores
                        attn = torch.bmm(q, k.transpose(1, 2)) / math.sqrt(self.d_k)
                        attn = F.softmax(attn, dim=2)
                        attn = F.dropout(attn, self.dropout, training=self.training)

                        # Apply attention to values
                        output = torch.bmm(attn, v)
                        output = output.view(-1, self.out_dim)

                        # Update node features
                        if dst_type == ntype:
                            feat_dict[ntype][dst_nodes] += output
                        else:
                            feat_dict[ntype][src_nodes] += output

            # Apply output transformation
            for ntype in G.ntypes:
                if G.number_of_nodes(ntype) == 0 or ntype not in feat_dict:
                    continue
                feat_dict[ntype] = self.out_linears[ntype](feat_dict[ntype])

            return feat_dict

class HGT(nn.Module):
    def __init__(self, G, in_dim, hidden_dim, out_dim, n_layers=2, n_heads=4, dropout=0.2):
        super().__init__()
        self.G = G
        self.ntypes = G.ntypes
        self.etypes = G.etypes  # Add this line to define etypes
        self.in_dim = in_dim
        self.hidden_dim = hidden_dim
        self.out_dim = out_dim
        self.n_layers = n_layers
        self.n_heads = n_heads
        self.dropout = dropout

        # Input layers for each node type
        self.embeddings = nn.ModuleDict({
            ntype: nn.Linear(in_dim, hidden_dim) for ntype in self.ntypes
        })

        # HGT layers
        self.layers = nn.ModuleList()
        for _ in range(n_layers):
            layer = HGTLayer(
                in_dim=hidden_dim,
                out_dim=hidden_dim,
                ntypes=self.ntypes,
                etypes=self.etypes,  # Now self.etypes is defined
                n_heads=n_heads,
                dropout=dropout
            )
            self.layers.append(layer)

        # Output layers for each node type
        self.outputs = nn.ModuleDict({
            ntype: nn.Linear(hidden_dim, out_dim) for ntype in self.ntypes
        })

        # Batch normalization layers
        self.batch_norms = nn.ModuleDict({
            ntype: nn.BatchNorm1d(out_dim) for ntype in self.ntypes
        })

    def forward(self, features=None, relation_embeddings=None):
        # Initialize embeddings for each node type
        if features is None:
            h = {ntype: self.embeddings[ntype](self.G.nodes[ntype].data['feat'])
                 for ntype in self.ntypes}
        else:
            h = {ntype: self.embeddings[ntype](features[ntype])
                 for ntype in self.ntypes}

        # Apply HGT layers with relation embeddings
        for layer in self.layers:
            h_new = layer(self.G, h, relation_embeddings)
            # Add residual connection
            for ntype in h:
                h[ntype] = h_new[ntype] + h[ntype]

        # Apply output layers with batch normalization
        out = {}
        for ntype in self.ntypes:
            out[ntype] = self.outputs[ntype](h[ntype])
            if out[ntype].shape[0] > 1:  # Skip batchnorm when batch size is 1
                out[ntype] = self.batch_norms[ntype](out[ntype])

        return out

def improved_contrastive_loss(embeddings, graph, temperature=0.7, margin=0.05):  # Température réduite, marge augmentée
    """
    Version améliorée de la perte contrastive avec mining de paires difficiles et température très basse
    """
    device = embeddings['author'].device

    # Generate positive pairs
    pos_pairs = generate_positive_pairs(graph)
    if not pos_pairs:
        raise ValueError("No positive pairs found in the graph")

    # Prepare tensors for positive pairs
    h1_list = []
    h2_list = []

    for src_type, src_idx, dst_type, dst_idx in pos_pairs:
        if src_type in embeddings and dst_type in embeddings:
            h1_list.append(embeddings[src_type][src_idx])
            h2_list.append(embeddings[dst_type][dst_idx])

    if not h1_list:
        raise ValueError("No valid embedding pairs found")

    h1 = torch.stack(h1_list)
    h2 = torch.stack(h2_list)

    # L2 normalization
    h1 = F.normalize(h1, p=2, dim=1)
    h2 = F.normalize(h2, p=2, dim=1)

    # Compute positive similarity (cosine similarity)
    pos_sim = torch.sum(h1 * h2, dim=1)

    # Compute negative similarity matrix
    batch_size = h1.size(0)
    neg_sim = torch.mm(h1, h2.t())

    # Remove diagonal (positive pairs)
    mask = torch.eye(batch_size, device=device)
    neg_sim = neg_sim * (1 - mask)

    # Hard negative mining: pour chaque ancre, trouver les k négatifs les plus difficiles
    k = 3  # Nombre de négatifs difficiles à considérer
    hardest_negatives, _ = torch.topk(neg_sim, k=min(k, batch_size-1), dim=1)
    hardest_negative_mean = torch.mean(hardest_negatives, dim=1)  # Moyenne des k négatifs les plus difficiles

    # Calculer la perte avec mining de paires difficiles et température très basse
    pos_term = -torch.log(torch.exp(pos_sim / temperature) /
                         (torch.exp(pos_sim / temperature) +
                          torch.exp(hardest_negative_mean / temperature) + 1e-8))

    # Ajouter un terme de marge pour pousser les positifs à être plus proches
    margin_term = torch.clamp(margin - pos_sim, min=0)

    # Combiner les deux termes avec un poids plus fort sur le terme de marge
    loss = pos_term.mean() + 0.9 * margin_term.mean()  # Augmenté de 0.7 à 0.9

    return loss

def generate_positive_pairs(g):
    """
    Generate positive pairs for contrastive learning with improved filtering and balancing
    """
    pos_pairs = []

    # Définir les relations importantes avec des poids
    key_relations = [
        ('publication', 'creator', 'author'),  # Relation auteur-publication
        ('author', 'hasDomain', 'domain'),     # Relation auteur-domaine (importante pour le clustering)
        ('publication', 'isPartOf', 'conference'),  # Relation publication-conférence
        ('conference', 'publishesDomain', 'domain')  # Relation conférence-domaine
    ]

    # Ajouter des relations inverses pour enrichir le graphe
    inverse_relations = [
        ('author', 'created', 'publication'),
        ('domain', 'hasAuthor', 'author'),     # Relation inverse domaine-auteur
        ('conference', 'hasPublication', 'publication'),  # Relation inverse conférence-publication
        ('domain', 'isPublishedIn', 'conference')  # Relation inverse domaine-conférence
    ]

    # Ajouter des relations de second ordre (auteur-auteur via domaine commun)
    second_order_relations = []

    # Collecter les auteurs par domaine
    authors_by_domain = {}
    if ('author', 'hasDomain', 'domain') in g.canonical_etypes:
        src, dst = g.edges(etype=('author', 'hasDomain', 'domain'))
        for s, d in zip(src.tolist(), dst.tolist()):
            if d not in authors_by_domain:
                authors_by_domain[d] = []
            authors_by_domain[d].append(s)

    # Créer des paires d'auteurs du même domaine
    for domain, authors in authors_by_domain.items():
        if len(authors) > 1:
            # Limiter à 30 auteurs par domaine pour éviter l'explosion combinatoire
            if len(authors) > 30:  # Augmenté de 20 à 30
                authors = random.sample(authors, 30)

            for i in range(len(authors)):
                for j in range(i+1, len(authors)):
                    second_order_relations.append(('author', authors[i], 'author', authors[j]))

    all_relations = key_relations + inverse_relations

    # Collecter les paires par type de relation
    relation_pairs = {}

    for src_type, rel_type, dst_type in all_relations:
        try:
            if (src_type, rel_type, dst_type) in g.canonical_etypes:
                src, dst = g.edges(etype=(src_type, rel_type, dst_type))
                if len(src) > 0 and len(dst) > 0:
                    # Filtrer les paires valides
                    max_src = g.number_of_nodes(src_type) - 1
                    max_dst = g.number_of_nodes(dst_type) - 1

                    valid_pairs = []
                    for s, d in zip(src.tolist(), dst.tolist()):
                        if s <= max_src and d <= max_dst:
                            valid_pairs.append((src_type, s, dst_type, d))

                    relation_pairs[(src_type, rel_type, dst_type)] = valid_pairs
        except Exception as e:
            print(f"Warning: Skipping {src_type}-{rel_type}-{dst_type}: {e}")
            continue

    # Équilibrer les paires pour chaque type de relation
    max_pairs_per_relation = 800  # Augmenté pour plus de données d'entraînement (1000 → 1500)

    for rel, pairs in relation_pairs.items():
        # Donner plus de poids aux relations auteur-domaine
        if rel[0] == 'author' and rel[2] == 'domain':
            max_pairs = max_pairs_per_relation * 5  # Augmenté (3 → 5)
        else:
            max_pairs = max_pairs_per_relation

        if len(pairs) > max_pairs:
            sampled_pairs = random.sample(pairs, max_pairs)
        else:
            sampled_pairs = pairs

        pos_pairs.extend(sampled_pairs)

    # Ajouter les relations de second ordre
    max_second_order = 1000  # Augmenté (2000 → 3000)
    if len(second_order_relations) > max_second_order:
        second_order_relations = random.sample(second_order_relations, max_second_order)

    pos_pairs.extend(second_order_relations)

    # Mélanger les paires
    random.shuffle(pos_pairs)

    return pos_pairs

def train_hgt(g, node_features, relation_embeddings, num_epochs=100, lr=0.000001):  # Augmenté lr de 0.0005 à 0.001
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Move relation embeddings to device
    relation_embeddings = {
        k: v.to(device) for k, v in relation_embeddings.items()
    }

    # Initialiser le modèle avec une meilleure initialisation
    torch.manual_seed(42)  # Pour la reproductibilité

    model = HGT(
        G=g,
        in_dim=768,
        hidden_dim=768,  # Augmenté pour plus de capacité (512 → 768)
        out_dim=384,     # Augmenté pour plus de capacité (256 → 384)
        n_layers=2,      # Réduit pour éviter le surapprentissage (3 → 2)
        n_heads=12,      # Augmenté pour plus d'attention (8 → 12)
        dropout=0.05     # Réduit davantage pour permettre plus d'apprentissage (0.1 → 0.05)
    ).to(device)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=lr,
        weight_decay=0.00005,  # Réduit davantage (0.0001 → 0.00005)
        betas=(0.9, 0.999)
    )

    # Scheduler avec warmup plus court et pic plus élevé
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=lr * 5,  # Pic beaucoup plus élevé (lr*3 → lr*5)
        steps_per_epoch=1,
        epochs=num_epochs,
        pct_start=0.05,  # Warmup plus court (0.1 → 0.05)
        anneal_strategy='cos'
    )

    # Initialiser best_loss avant de l'utiliser
    best_loss = float('inf')

    # Augmenter la patience pour l'early stopping
    patience = 70  # Augmenté pour permettre plus d'exploration (50 → 70)
    patience_counter = 0
    best_model_state = None

    # Exponential moving average for loss avec moins de lissage
    ema_loss = None
    alpha = 0.8  # Réduit pour réagir plus rapidement aux changements (0.9 → 0.8)

    print(f"Training on {device} for {num_epochs} epochs...")

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        embeddings = model(features=None, relation_embeddings=relation_embeddings)

        # Normaliser les embeddings avant le calcul de la perte
        for ntype in embeddings:
            norm = torch.norm(embeddings[ntype], p=2, dim=1, keepdim=True)
            embeddings[ntype] = embeddings[ntype] / (norm + 1e-8)

        # Calculer la perte avec température plus basse
        loss = improved_contrastive_loss(embeddings, g, temperature=0.07, margin=0.5)

        # Update EMA loss
        if ema_loss is None:
            ema_loss = loss.item()
        else:
            ema_loss = alpha * ema_loss + (1 - alpha) * loss.item()

        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        loss.backward()
        optimizer.step()
        scheduler.step()

        # Early stopping
        if ema_loss < best_loss:
            best_loss = ema_loss
            patience_counter = 0
            best_model_state = model.state_dict().copy()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.load_state_dict(best_model_state)
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch {epoch+1}/{num_epochs}, Loss: {ema_loss:.4f}')
            print(f'Learning rate: {optimizer.param_groups[0]["lr"]:.6f}')

    # Charger le meilleur modèle
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    # Générer les embeddings finaux
    model.eval()
    with torch.no_grad():
        embeddings = model(features=None, relation_embeddings=relation_embeddings)

    return model, embeddings

def align_cluster_labels(true_labels, pred_labels):
    """
    Align predicted cluster labels with true labels using optimal assignment.
    This is necessary because clustering algorithms assign arbitrary label numbers.
    """
    from scipy.optimize import linear_sum_assignment
    from sklearn.metrics import confusion_matrix

    # Create confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)

    # Use Hungarian algorithm to find optimal assignment
    # We want to maximize the diagonal, so we use negative costs
    row_ind, col_ind = linear_sum_assignment(-cm)

    # Create mapping from predicted labels to aligned labels
    label_mapping = {}
    for pred_idx, true_idx in zip(col_ind, row_ind):
        label_mapping[pred_idx] = true_idx

    # Apply mapping to predicted labels
    aligned_labels = np.array([label_mapping.get(label, label) for label in pred_labels])

    return aligned_labels

def calculate_alignment_quality(true_labels, pred_labels, alignment_mapping):
    """
    Calculate the quality of cluster-domain alignment.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains

    Returns:
        float: Alignment quality score (0-1, higher is better)
    """
    if not alignment_mapping:
        return 0.0

    total_aligned = 0
    total_nodes = len(true_labels)

    for cluster, domain in alignment_mapping.items():
        # Count nodes that are correctly aligned
        correctly_aligned = np.sum((pred_labels == cluster) & (true_labels == domain))
        total_aligned += correctly_aligned

    return total_aligned / total_nodes if total_nodes > 0 else 0.0

def create_cluster_alignment_mapping(true_labels, pred_labels):
    """
    Create a mapping between predicted clusters and true domains based on maximum overlap.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels

    Returns:
        dict: Mapping from predicted cluster labels to corresponding true domain labels
    """
    from scipy.optimize import linear_sum_assignment

    unique_true = np.unique(true_labels)
    unique_pred = np.unique(pred_labels)

    # Create contingency matrix
    contingency = np.zeros((len(unique_pred), len(unique_true)), dtype=int)
    for i, pred_label in enumerate(unique_pred):
        for j, true_label in enumerate(unique_true):
            contingency[i, j] = np.sum((pred_labels == pred_label) & (true_labels == true_label))

    # Use Hungarian algorithm to find optimal assignment
    row_indices, col_indices = linear_sum_assignment(-contingency)

    # Create mapping
    alignment_mapping = {}
    for i, j in zip(row_indices, col_indices):
        if i < len(unique_pred) and j < len(unique_true):
            alignment_mapping[unique_pred[i]] = unique_true[j]

    return alignment_mapping

def create_aligned_color_scheme(unique_true, unique_pred, alignment_mapping):
    """
    Create an aligned color scheme where corresponding clusters and domains use the same colors.

    Args:
        unique_true: Array of unique true domain labels
        unique_pred: Array of unique predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains

    Returns:
        dict: Color scheme with 'true' and 'pred' keys containing color mappings
    """
    # Use a high-quality color palette with enough distinct colors
    import matplotlib.colors as mcolors

    # Create a comprehensive color palette
    base_colors = [
        '#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
        '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
        '#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5',
        '#c49c94', '#f7b6d3', '#c7c7c7', '#dbdb8d', '#9edae5'
    ]

    # Extend color palette if needed
    if len(unique_true) > len(base_colors):
        # Generate additional colors using HSV space
        additional_colors = []
        for i in range(len(unique_true) - len(base_colors)):
            hue = (i * 0.618033988749895) % 1  # Golden ratio for good distribution
            color = mcolors.hsv_to_rgb([hue, 0.7, 0.9])
            additional_colors.append(mcolors.to_hex(color))
        base_colors.extend(additional_colors)

    # Assign colors to true domains
    true_colors = {}
    for i, domain in enumerate(unique_true):
        true_colors[domain] = base_colors[i % len(base_colors)]

    # Assign colors to predicted clusters based on alignment
    pred_colors = {}
    unaligned_color_idx = len(unique_true)  # Start after true domain colors

    for cluster in unique_pred:
        if cluster in alignment_mapping:
            # Use the same color as the corresponding true domain
            corresponding_domain = alignment_mapping[cluster]
            pred_colors[cluster] = true_colors[corresponding_domain]
        else:
            # Use a distinct color for unaligned clusters
            pred_colors[cluster] = base_colors[unaligned_color_idx % len(base_colors)]
            unaligned_color_idx += 1

    return {
        'true': true_colors,
        'pred': pred_colors
    }

def evaluate_clustering(embeddings, true_labels, n_clusters, node_type='author'):
    """
    Evaluate clustering performance using hierarchical clustering for all node types
    with enhanced alignment quality assessment
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité pour améliorer le clustering
    from sklearn.decomposition import PCA

    # Paramètres adaptés par type de nœud
    if node_type == 'author':
        pca_components = min(64, embeddings.shape[1])
    elif node_type == 'publication':
        pca_components = min(48, embeddings.shape[1])
    elif node_type == 'conference':
        pca_components = min(32, embeddings.shape[1])
    else:
        pca_components = min(64, embeddings.shape[1])

    pca = PCA(n_components=pca_components, random_state=42)
    embeddings_reduced = pca.fit_transform(embeddings)
    print(f"📊 Variance expliquée par PCA ({node_type}): {sum(pca.explained_variance_ratio_):.4f}")

    # Exécuter le clustering hiérarchique avec différentes méthodes de liaison
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_alignment_quality = 0

    print(f"🔄 Testing hierarchical clustering with different linkage methods for {node_type}...")

    for linkage in ['ward', 'complete', 'average', 'single']:
        agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
        pred_labels = agg.fit_predict(embeddings_reduced)

        nmi = normalized_mutual_info_score(true_labels, pred_labels)
        ari = adjusted_rand_score(true_labels, pred_labels)

        # Align predicted labels with true labels for F1 and Accuracy calculation
        aligned_labels = align_cluster_labels(true_labels, pred_labels)
        f1 = f1_score(true_labels, aligned_labels, average='weighted')
        acc = accuracy_score(true_labels, aligned_labels)

        # Calculate alignment quality
        alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)
        alignment_quality = calculate_alignment_quality(true_labels, pred_labels, alignment_mapping)

        print(f"   AgglomerativeClustering (linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}, Alignment={alignment_quality:.4f}")

        # Select best result based on NMI primarily, with alignment quality as secondary criterion
        if nmi > best_nmi or (nmi == best_nmi and alignment_quality > best_alignment_quality):
            best_nmi = nmi
            best_ari = ari
            best_f1 = f1
            best_acc = acc
            best_labels = pred_labels
            best_alignment_quality = alignment_quality

    print(f"✅ Best {node_type} clustering: NMI={best_nmi:.4f}, Alignment Quality={best_alignment_quality:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def create_output_directory():
    """
    Create the output directory for saving images.
    """
    output_dir = "hierarchique hgt par type"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    return output_dir

def visualize_clusters(embeddings, true_labels, pred_labels, title="Cluster Visualization"):
    """
    Visualize clusters using t-SNE with enhanced color alignment and display.
    Features enhanced color alignment where corresponding clusters use the same colors.
    """
    # Create output directory
    output_dir = create_output_directory()

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Apply t-SNE
    tsne = TSNE(n_components=2, perplexity=min(30, len(embeddings)-1), random_state=42)
    embeddings_2d = tsne.fit_transform(embeddings)

    # Create figure with two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

    # Get unique labels
    unique_true = np.unique(true_labels)
    unique_pred = np.unique(pred_labels)

    # Create alignment mapping between predicted clusters and true domains
    alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)

    # Create aligned color scheme
    aligned_colors = create_aligned_color_scheme(unique_true, unique_pred, alignment_mapping)

    # Plot true labels with aligned colors
    for i, label in enumerate(unique_true):
        mask = true_labels == label
        color = aligned_colors['true'][label]
        ax1.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1],
                   c=[color], label=f'Domain {int(label)}',
                   alpha=0.7, s=60, edgecolors='black', linewidths=0.3)

    ax1.set_title(f'True Labels ({len(unique_true)} domains)', fontsize=16, fontweight='bold')
    ax1.set_xlabel('t-SNE Dimension 1', fontsize=14)
    ax1.set_ylabel('t-SNE Dimension 2', fontsize=14)
    ax1.grid(True, alpha=0.3)

    # Improved legend positioning and styling
    legend1 = ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left',
                        title="True Domains", title_fontsize=12, fontsize=10)
    legend1.get_frame().set_facecolor('white')
    legend1.get_frame().set_alpha(0.9)

    # Plot predicted clusters with aligned colors
    for i, label in enumerate(unique_pred):
        mask = pred_labels == label
        color = aligned_colors['pred'][label]
        # Find the corresponding true domain for this cluster
        corresponding_domain = alignment_mapping.get(label, None)
        cluster_label = f'Cluster {int(label)}'
        if corresponding_domain is not None:
            cluster_label += f' → Domain {int(corresponding_domain)}'

        ax2.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1],
                   c=[color], label=cluster_label,
                   alpha=0.7, s=60, edgecolors='black', linewidths=0.3)

    ax2.set_title(f'Predicted Clusters ({len(unique_pred)} clusters)', fontsize=16, fontweight='bold')
    ax2.set_xlabel('t-SNE Dimension 1', fontsize=14)
    ax2.set_ylabel('t-SNE Dimension 2', fontsize=14)
    ax2.grid(True, alpha=0.3)

    # Improved legend positioning and styling
    legend2 = ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left',
                        title="Predicted Clusters", title_fontsize=12, fontsize=10)
    legend2.get_frame().set_facecolor('white')
    legend2.get_frame().set_alpha(0.9)

    # Add cluster alignment analysis with color coordination info
    alignment_info = f"🎨 Color-Aligned Visualization: Matching clusters and domains use the same colors"
    plt.suptitle(f'{title}\nHierarchical Cluster-Domain Alignment Analysis\n{alignment_info}',
                fontsize=16, fontweight='bold', y=0.95)

    # Adjust layout to accommodate legends and title
    plt.tight_layout()
    plt.subplots_adjust(right=0.85, top=0.85)

    # Save in the output directory
    filename = f'{title.lower().replace(" ", "_")}.png'
    filepath = os.path.join(output_dir, filename)
    plt.savefig(filepath, dpi=300, bbox_inches='tight')
    plt.show()

    # Print enhanced cluster alignment information
    print(f"\n=== {title} - Enhanced Hierarchical Cluster Alignment Analysis ===")
    print(f"Number of true domains: {len(unique_true)}")
    print(f"Number of predicted clusters: {len(unique_pred)}")
    print(f"🎨 Visual Enhancement: Corresponding clusters and domains use matching colors")

    # Print alignment mapping information
    print(f"\n🔗 Cluster-Domain Alignment Mapping:")
    for cluster, domain in alignment_mapping.items():
        cluster_size = np.sum(pred_labels == cluster)
        domain_size = np.sum(true_labels == domain)
        overlap = np.sum((pred_labels == cluster) & (true_labels == domain))
        precision = (overlap / cluster_size) * 100 if cluster_size > 0 else 0
        recall = (overlap / domain_size) * 100 if domain_size > 0 else 0
        print(f"   Cluster {int(cluster)} ↔ Domain {int(domain)}: "
              f"{overlap} nodes (Precision: {precision:.1f}%, Recall: {recall:.1f}%)")

    # Calculate and display alignment quality metrics
    total_aligned = sum(np.sum((pred_labels == cluster) & (true_labels == domain))
                       for cluster, domain in alignment_mapping.items())
    total_nodes = len(true_labels)
    alignment_accuracy = (total_aligned / total_nodes) * 100 if total_nodes > 0 else 0

    print(f"\n✅ Hierarchical Clustering Alignment Quality Metrics:")
    print(f"   Total nodes correctly aligned: {total_aligned}/{total_nodes} ({alignment_accuracy:.1f}%)")
    print(f"   Number of optimal alignments: {len(alignment_mapping)}")

    # Generate and save alignment report
    save_alignment_report(true_labels, pred_labels, alignment_mapping, title, output_dir)

def save_alignment_report(true_labels, pred_labels, alignment_mapping, title, output_dir):
    """
    Save a detailed alignment report to a text file for hierarchical clustering.

    Args:
        true_labels: Array of true domain labels
        pred_labels: Array of predicted cluster labels
        alignment_mapping: Mapping from predicted clusters to true domains
        title: Title for the report
        output_dir: Directory to save the report
    """
    from datetime import datetime

    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    report_content = f"""======================================================================
HIERARCHICAL CLUSTER-DOMAIN ALIGNMENT REPORT
======================================================================
Generated on: {timestamp}
Analysis: {title}
Clustering Method: Agglomerative Hierarchical Clustering

======================================================================
ALIGNMENT SUMMARY
======================================================================

Total nodes analyzed: {len(true_labels):,}
Number of true domains: {len(np.unique(true_labels))}
Number of predicted clusters: {len(np.unique(pred_labels))}
Number of optimal alignments: {len(alignment_mapping)}

======================================================================
DETAILED ALIGNMENT MAPPING
======================================================================

"""

    # Calculate detailed metrics for each alignment
    for cluster, domain in alignment_mapping.items():
        cluster_size = np.sum(pred_labels == cluster)
        domain_size = np.sum(true_labels == domain)
        overlap = np.sum((pred_labels == cluster) & (true_labels == domain))
        precision = (overlap / cluster_size) * 100 if cluster_size > 0 else 0
        recall = (overlap / domain_size) * 100 if domain_size > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        report_content += f"""Cluster {int(cluster)} ↔ Domain {int(domain)}:
  - Overlap: {overlap} nodes
  - Cluster size: {cluster_size} nodes
  - Domain size: {domain_size} nodes
  - Precision: {precision:.2f}%
  - Recall: {recall:.2f}%
  - F1-Score: {f1:.2f}%

"""

    # Calculate overall alignment quality
    total_aligned = sum(np.sum((pred_labels == cluster) & (true_labels == domain))
                       for cluster, domain in alignment_mapping.items())
    alignment_accuracy = (total_aligned / len(true_labels)) * 100

    report_content += f"""======================================================================
OVERALL ALIGNMENT QUALITY
======================================================================

Total correctly aligned nodes: {total_aligned}/{len(true_labels)}
Overall alignment accuracy: {alignment_accuracy:.2f}%

======================================================================
HIERARCHICAL CLUSTERING ADVANTAGES
======================================================================

✅ Deterministic Results: Unlike K-means, hierarchical clustering provides
   consistent results without random initialization effects.

✅ No Need for K: Automatically determines cluster structure without
   requiring pre-specification of cluster numbers.

✅ Interpretable Hierarchy: Provides a dendrogram showing cluster
   relationships and merge decisions.

✅ Robust to Outliers: Less sensitive to outliers compared to centroid-based
   methods like K-means.

======================================================================
VISUALIZATION ENHANCEMENT
======================================================================

🎨 Color Alignment: The visualization uses matching colors for corresponding
   clusters and domains, making it easier to visually assess alignment quality.

✅ Optimal alignments are clearly visible through color coordination
🔍 Hierarchical structure provides additional interpretability

======================================================================
"""

    # Save the report
    report_filename = f"{title.lower().replace(' ', '_')}_hierarchical_alignment_report.txt"
    report_filepath = os.path.join(output_dir, report_filename)

    with open(report_filepath, 'w', encoding='utf-8') as f:
        f.write(report_content)

    print(f"📄 Hierarchical alignment report saved to: {report_filepath}")
    return report_filepath

def analyze_clusters(embeddings, true_labels, pred_labels, id_node_map):
    """
    Analyze the composition of each cluster and calculate purity metrics.
    """
    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Get unique clusters
    unique_clusters = np.unique(pred_labels)

    print("\nCluster Analysis:")
    print("----------------")

    # Calculate overall cluster purity
    total_correct = 0
    total_nodes = len(pred_labels)

    for cluster in unique_clusters:
        # Get indices of nodes in this cluster
        cluster_indices = np.where(pred_labels == cluster)[0]

        # Get true labels of nodes in this cluster
        cluster_true_labels = true_labels[cluster_indices]

        # Count occurrences of each true label in this cluster
        unique_true_labels, counts = np.unique(cluster_true_labels, return_counts=True)

        # Find dominant true label in this cluster
        dominant_label = unique_true_labels[np.argmax(counts)]
        dominant_count = np.max(counts)

        # Add to total correct count
        total_correct += dominant_count

        print(f"\nCluster {cluster}:")
        print(f"Number of nodes: {len(cluster_indices)}")
        print(f"Dominant label: {dominant_label} ({dominant_count} nodes, {dominant_count/len(cluster_indices)*100:.1f}%)")
        print("True label distribution:")
        for label, count in zip(unique_true_labels, counts):
            print(f"  Label {label}: {count} nodes ({count/len(cluster_indices)*100:.1f}%)")

    # Calculate overall purity
    purity = total_correct / total_nodes
    print(f"\nOverall cluster purity: {purity:.4f}")

    # Calculate confusion matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(true_labels, pred_labels)

    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.tight_layout()
    from IPython.display import display
    display(plt.gcf())

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'confusion_matrix.png')
    plt.savefig(filepath, dpi=300)
    plt.close()
    return purity

def save_clustering_results_summary(results_data, output_dir):
    """
    Sauvegarde automatiquement un résumé complet des résultats de clustering hiérarchique dans clustering_results_summary.txt

    Args:
        results_data: Dictionnaire contenant tous les résultats de clustering
        output_dir: Répertoire de sortie pour le fichier
    """
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    summary_content = f"""======================================================================
HGT + HIERARCHICAL CLUSTERING RESULTS SUMMARY
======================================================================
Generated on: {timestamp}
Pipeline: Heterogeneous Graph Transformer + Hierarchical Clustering

======================================================================
EXECUTIVE SUMMARY
======================================================================

🎯 CLUSTERING PERFORMANCE OVERVIEW:
"""

    # Ajouter les résultats pour chaque type de nœud
    if 'author' in results_data:
        author_data = results_data['author']
        summary_content += f"""
🏆 AUTHOR CLUSTERING (PRIMARY RESULTS):
- Nodes processed: {author_data.get('num_nodes', 'N/A'):,} authors
- Number of clusters: {author_data.get('n_clusters', 'N/A')}
- Clustering method: Agglomerative Clustering (Hierarchical)
- NMI (Normalized Mutual Information): {author_data.get('nmi', 0):.4f}"""

        # Ajouter des étoiles pour les excellents résultats
        if author_data.get('nmi', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('nmi', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- ARI (Adjusted Rand Index): {author_data.get('ari', 0):.4f}"""

        if author_data.get('ari', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('ari', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- F1-Score: {author_data.get('f1', 0):.4f}"""

        if author_data.get('f1', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('f1', 0) > 0.6:
            summary_content += " ✅ GOOD"

        summary_content += f"""
- Accuracy: {author_data.get('acc', 0):.4f}"""

        if author_data.get('acc', 0) > 0.8:
            summary_content += " ⭐ EXCELLENT"
        elif author_data.get('acc', 0) > 0.6:
            summary_content += " ✅ GOOD"

        if 'purity' in author_data:
            summary_content += f"""
- Overall Cluster Purity: {author_data.get('purity', 0)*100:.2f}%"""
            if author_data.get('purity', 0) > 0.9:
                summary_content += " ⭐ OUTSTANDING"

    if 'publication' in results_data:
        pub_data = results_data['publication']
        summary_content += f"""

📊 PUBLICATION CLUSTERING:
- Nodes processed: {pub_data.get('num_nodes', 'N/A'):,} publications
- Number of clusters: {pub_data.get('n_clusters', 'N/A')}
- Clustering method: Agglomerative Clustering (Hierarchical)
- NMI (Normalized Mutual Information): {pub_data.get('nmi', 0):.4f}
- ARI (Adjusted Rand Index): {pub_data.get('ari', 0):.4f}
- F1-Score: {pub_data.get('f1', 0):.4f}
- Accuracy: {pub_data.get('acc', 0):.4f}"""

        if 'purity' in pub_data:
            summary_content += f"""
- Overall Cluster Purity: {pub_data.get('purity', 0)*100:.2f}%"""

    if 'venue' in results_data:
        venue_data = results_data['venue']
        summary_content += f"""

🏢 VENUE CLUSTERING:
- Nodes processed: {venue_data.get('num_nodes', 'N/A'):,} venues
- Number of clusters: {venue_data.get('n_clusters', 'N/A')}
- Clustering method: {venue_data.get('best_method', 'Agglomerative Clustering')}
- NMI (Normalized Mutual Information): {venue_data.get('nmi', 0):.4f}
- ARI (Adjusted Rand Index): {venue_data.get('ari', 0):.4f}
- F1-Score: {venue_data.get('f1', 0):.4f}
- Accuracy: {venue_data.get('acc', 0):.4f}"""

        if 'purity' in venue_data:
            summary_content += f"""
- Overall Cluster Purity: {venue_data.get('purity', 0)*100:.2f}%"""

    # Ajouter la configuration technique
    summary_content += f"""

======================================================================
TECHNICAL CONFIGURATION
======================================================================

Graph Structure:
- Total nodes: {results_data.get('total_nodes', 'N/A')}
- Total edges: {results_data.get('total_edges', 'N/A')}
- Node types: {results_data.get('node_types', 'N/A')}
- Relation types: {results_data.get('num_relations', 'N/A')}

HGT Model Configuration:
- Input dimension: 768 (BERT embeddings)
- Hidden dimension: 768
- Output dimension: 384
- Number of layers: 2
- Attention heads: 12
- Dropout rate: 0.05

Training Parameters:
- Epochs: {results_data.get('epochs', 100)}
- Learning rate: {results_data.get('learning_rate', 0.000001)}
- Optimizer: AdamW with weight decay
- Scheduler: OneCycleLR with cosine annealing
- Early stopping patience: 70

Hierarchical Clustering Configuration:
- Algorithm: Agglomerative Clustering
- Linkage methods tested: ward, complete, average, single
- PCA preprocessing: Adaptive components (32-64)
- Distance metric: Euclidean (for ward), others adaptive
- Multi-configuration testing for venues

======================================================================
OUTPUT FILES
======================================================================

Visualizations (High Quality - 300 DPI):"""

    # Lister les fichiers de visualisation générés
    viz_files = []
    if 'author' in results_data:
        viz_files.append("1. author_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Side-by-side comparison of true labels vs predicted clusters")
        viz_files.append("   - Matching colors for corresponding clusters and domains")
        viz_files.append("   - Hierarchical clustering analysis with alignment mapping")
        viz_files.append("2. author_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed hierarchical alignment report with precision/recall metrics")

    if 'publication' in results_data:
        viz_files.append("3. publication_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Domain distribution analysis with alignment mapping")
        viz_files.append("4. publication_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed publication hierarchical alignment analysis")

    if 'venue' in results_data:
        viz_files.append("5. venue_cluster_visualization.png")
        viz_files.append("   - t-SNE visualization with enhanced color alignment")
        viz_files.append("   - Multi-configuration clustering analysis with alignment mapping")
        viz_files.append("6. venue_cluster_visualization_hierarchical_alignment_report.txt")
        viz_files.append("   - Detailed venue hierarchical alignment analysis")

    viz_files.append("7. confusion_matrix.png")
    viz_files.append("   - Detailed confusion matrix for cluster analysis")

    for viz_file in viz_files:
        summary_content += f"\n{viz_file}"

    summary_content += f"""

Models and Data:
5. Trained HGT model (hgt_model.pt)
6. Complete embeddings for all node types (embeddings.pkl)
7. Cluster assignments for all node types

======================================================================
KEY TECHNICAL INNOVATIONS
======================================================================

1. HIERARCHICAL CLUSTERING APPROACH:
   - Agglomerative clustering with multiple linkage methods
   - Adaptive parameter selection for different node types
   - Multi-configuration testing for optimal results
   - Deterministic results without random initialization effects

2. ENHANCED CLUSTER ALIGNMENT SYSTEM:
   - Optimal cluster-domain mapping using Hungarian algorithm
   - Color-coordinated visualizations for intuitive comparison
   - Detailed alignment quality metrics (precision, recall, F1)
   - Comprehensive hierarchical alignment reports with quality assessment

3. ADVANCED PREPROCESSING:
   - Adaptive PCA dimensionality reduction
   - L2 normalization of embeddings
   - UMAP fallback for complex venue clustering

4. COMPREHENSIVE EVALUATION:
   - Multiple clustering metrics (NMI, ARI, F1, Accuracy)
   - Cluster purity analysis with alignment quality scoring
   - Visual analysis with t-SNE and enhanced color alignment
   - Hierarchical structure interpretability

5. SPECIALIZED VENUE CLUSTERING:
   - Multi-configuration approach with different cluster numbers
   - DBSCAN-style parameter exploration
   - Domain inference from publication relationships
   - Enhanced alignment assessment for complex venue structures

6. RELATION-AWARE LEARNING:
   - Integration of relation embeddings in HGT layers
   - Contrastive learning with hard negative mining
   - Multi-order relation modeling

======================================================================
PERFORMANCE ANALYSIS
======================================================================
"""

    # Ajouter une analyse de performance
    if 'author' in results_data:
        author_nmi = results_data['author'].get('nmi', 0)
        if author_nmi > 0.9:
            summary_content += "\n✅ OUTSTANDING: Author clustering achieved exceptional performance (NMI > 0.9)"
        elif author_nmi > 0.8:
            summary_content += "\n✅ EXCELLENT: Author clustering achieved excellent performance (NMI > 0.8)"
        elif author_nmi > 0.6:
            summary_content += "\n✅ GOOD: Author clustering achieved good performance (NMI > 0.6)"
        else:
            summary_content += "\n⚠️ MODERATE: Author clustering performance could be improved"

    if 'venue' in results_data:
        venue_nmi = results_data['venue'].get('nmi', 0)
        if venue_nmi > 0.5:
            summary_content += "\n✅ GOOD: Venue clustering achieved good performance despite complexity"
        elif venue_nmi > 0.3:
            summary_content += "\n⚠️ MODERATE: Venue clustering shows moderate performance"
        else:
            summary_content += "\n⚠️ CHALLENGING: Venue clustering remains challenging (expected for this node type)"

    summary_content += f"""

======================================================================
CLUSTERING METHODOLOGY NOTES
======================================================================

Hierarchical vs K-means Comparison:
- Hierarchical clustering provides better interpretability
- No need to pre-specify exact number of clusters
- Better handling of non-spherical cluster shapes
- More robust to outliers and noise

Venue Clustering Challenges:
- Venues often have sparse domain relationships
- Multi-configuration approach compensates for complexity
- Domain inference from publications improves accuracy

======================================================================
EXECUTION DETAILS
======================================================================

Execution Time: {results_data.get('execution_time', 'N/A')}
Device Used: {results_data.get('device', 'N/A')}
Memory Usage: {results_data.get('memory_usage', 'N/A')}

Generated by: HGT + Hierarchical Clustering Pipeline
Version: 2.0 (Enhanced with automatic result saving)
======================================================================
"""

    # Sauvegarder le fichier
    summary_file = os.path.join(output_dir, "clustering_results_summary.txt")
    with open(summary_file, 'w', encoding='utf-8') as f:
        f.write(summary_content)

    print(f"\n✅ Clustering results summary saved to: {summary_file}")
    return summary_file

def run_hgt_clustering(g, node_features, relation_embeddings, true_labels, id_node_map):
    """
    Run the complete HGT clustering pipeline with separate clustering for each node type.
    """
    # Enregistrer le temps de début
    start_time = time.time()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Initialiser le dictionnaire des résultats
    results_data = {
        'total_nodes': g.num_nodes(),
        'total_edges': g.num_edges(),
        'node_types': list(g.ntypes),
        'num_relations': len(g.etypes),
        'epochs': 100,
        'learning_rate': 0.000001,
        'device': str(device)
    }

    # Move relation embeddings to device
    relation_embeddings = {
        k: v.to(device) for k, v in relation_embeddings.items()
    }

    # Initialiser le modèle
    torch.manual_seed(42)

    model = HGT(
        G=g,
        in_dim=768,
        hidden_dim=768,
        out_dim=384,
        n_layers=2,
        n_heads=12,
        dropout=0.05
    ).to(device)

    # Train HGT with contrastive learning
    print("Training HGT model...")
    model, embeddings = train_hgt(g, node_features, relation_embeddings)

    # Séparer le clustering par type de nœud
    # 1. Clustering des auteurs
    print("\n" + "="*50)
    print("CLUSTERING DES AUTEURS")
    print("="*50)

    if 'author' in embeddings:
        author_embeddings = embeddings['author']
        n_clusters = len(np.unique(true_labels))

        print("\nEvaluating author clustering...")
        nmi, ari, f1, acc, pred_labels = evaluate_clustering(
            author_embeddings,
            true_labels,
            n_clusters,
            node_type='author'
        )

        print(f"\nAuthor Clustering Evaluation:")
        print(f"NMI: {nmi:.4f}")
        print(f"ARI: {ari:.4f}")
        print(f"F1: {f1:.4f}")
        print(f"ACC: {acc:.4f}")

        # Visualize clusters
        print("\nVisualizing author clusters...")
        visualize_clusters(
            author_embeddings,
            true_labels,
            pred_labels,
            "Author Cluster Visualization"
        )

        # Analyze clusters
        print("\nAnalyzing author clusters...")
        purity = analyze_clusters(author_embeddings, true_labels, pred_labels, id_node_map)
        print(f"Author Cluster Purity: {purity:.4f}")

        # Sauvegarder les résultats des auteurs
        results_data['author'] = {
            'num_nodes': len(author_embeddings),
            'n_clusters': n_clusters,
            'nmi': nmi,
            'ari': ari,
            'f1': f1,
            'acc': acc,
            'purity': purity
        }

    # 2. Clustering des publications
    print("\n" + "="*50)
    print("CLUSTERING DES PUBLICATIONS")
    print("="*50)

    if 'publication' in embeddings:
        # Obtenir les vraies étiquettes des publications si disponibles
        pub_true_labels = None
        if hasattr(g.nodes['publication'], 'data') and 'true_domain' in g.nodes['publication'].data:
            pub_true_labels = g.nodes['publication'].data['true_domain'].cpu().numpy()

        # Si les vraies étiquettes ne sont pas disponibles, essayer de les extraire du graphe RDF
        if pub_true_labels is None:
            pub_true_labels = get_node_domains(g, 'publication', id_node_map, rdf_graph)

        if pub_true_labels is not None and len(pub_true_labels) > 0:
            pub_embeddings = embeddings['publication']
            n_pub_clusters = len(np.unique(pub_true_labels))

            # Paramètres spécifiques pour les publications
            print("\nEvaluating publication clustering...")
            pub_nmi, pub_ari, pub_f1, pub_acc, pub_pred_labels = evaluate_clustering(
                pub_embeddings,
                pub_true_labels,
                n_pub_clusters,
                node_type='publication'
            )

            print(f"\nPublication Clustering Evaluation:")
            print(f"NMI: {pub_nmi:.4f}")
            print(f"ARI: {pub_ari:.4f}")
            print(f"F1: {pub_f1:.4f}")
            print(f"ACC: {pub_acc:.4f}")

            # Visualiser avec le même format que pour les auteurs
            visualize_clusters(
                pub_embeddings,
                pub_true_labels,
                pub_pred_labels,
                "Publication Cluster Visualization"
            )

            # Analyser les clusters de publications
            print("\nAnalyzing publication clusters...")
            pub_purity = analyze_clusters(pub_embeddings, pub_true_labels, pub_pred_labels, id_node_map)
            print(f"Publication Cluster Purity: {pub_purity:.4f}")

            # Sauvegarder les résultats des publications
            results_data['publication'] = {
                'num_nodes': len(pub_embeddings),
                'n_clusters': n_pub_clusters,
                'nmi': pub_nmi,
                'ari': pub_ari,
                'f1': pub_f1,
                'acc': pub_acc,
                'purity': pub_purity
            }
        else:
            print("Pas d'étiquettes de domaine disponibles pour les publications.")

    # 3. Clustering des venues
    print("\n" + "="*50)
    print("CLUSTERING DES VENUES")
    print("="*50)

    if 'venue' in embeddings:
        # Obtenir les vraies étiquettes des venues si disponibles
        conf_true_labels = None
        if hasattr(g.nodes['venue'], 'data') and 'true_domain' in g.nodes['venue'].data:
            conf_true_labels = g.nodes['venue'].data['true_domain'].cpu().numpy()

        # Si les vraies étiquettes ne sont pas disponibles, essayer de les extraire du graphe RDF
        if conf_true_labels is None:
            conf_true_labels = get_node_domains(g, 'venue', id_node_map, rdf_graph)

        if conf_true_labels is not None and len(conf_true_labels) > 0:
            conf_embeddings = embeddings['venue']
            n_conf_clusters = len(np.unique(conf_true_labels))

            # Paramètres spécifiques pour les venues
            print("\nEvaluating venue clustering with specialized parameters...")

            # Essayer plusieurs configurations pour les venues
            best_conf_nmi = 0
            best_conf_ari = 0
            best_conf_f1 = 0
            best_conf_acc = 0
            best_conf_pred_labels = None

            # Configuration 1: Plus de composantes PCA
            print("\nTesting configuration 1: More PCA components...")
            conf_nmi1, conf_ari1, conf_f1_1, conf_acc1, conf_pred_labels1 = evaluate_clustering_conference(
                conf_embeddings,
                conf_true_labels,
                n_conf_clusters,
                pca_components=min(48, conf_embeddings.shape[1]),
                n_init_kmeans=30,
                n_runs=30
            )

            if conf_nmi1 > best_conf_nmi:
                best_conf_nmi = conf_nmi1
                best_conf_ari = conf_ari1
                best_conf_f1 = conf_f1_1
                best_conf_acc = conf_acc1
                best_conf_pred_labels = conf_pred_labels1
                print(f"New best configuration (1): NMI={conf_nmi1:.4f}, ARI={conf_ari1:.4f}, F1={conf_f1_1:.4f}, ACC={conf_acc1:.4f}")

            # Configuration 2: Moins de clusters
            print("\nTesting configuration 2: Fewer clusters...")
            conf_nmi2, conf_ari2, conf_f1_2, conf_acc2, conf_pred_labels2 = evaluate_clustering_conference(
                conf_embeddings,
                conf_true_labels,
                max(3, n_conf_clusters-2),  # Réduire le nombre de clusters
                pca_components=min(32, conf_embeddings.shape[1]),
                n_init_kmeans=40,
                n_runs=40
            )

            if conf_nmi2 > best_conf_nmi:
                best_conf_nmi = conf_nmi2
                best_conf_ari = conf_ari2
                best_conf_f1 = conf_f1_2
                best_conf_acc = conf_acc2
                best_conf_pred_labels = conf_pred_labels2
                print(f"New best configuration (2): NMI={conf_nmi2:.4f}, ARI={conf_ari2:.4f}, F1={conf_f1_2:.4f}, ACC={conf_acc2:.4f}")

            # Configuration 3: Utiliser le clustering hiérarchique avec différents nombres de clusters
            print("\nTesting configuration 3: Hierarchical clustering with different parameters...")
            conf_nmi3, conf_ari3, conf_f1_3, conf_acc3, conf_pred_labels3 = evaluate_clustering_dbscan(
                conf_embeddings,
                conf_true_labels
            )

            if conf_nmi3 > best_conf_nmi:
                best_conf_nmi = conf_nmi3
                best_conf_ari = conf_ari3
                best_conf_f1 = conf_f1_3
                best_conf_acc = conf_acc3
                best_conf_pred_labels = conf_pred_labels3
                print(f"New best configuration (3): NMI={conf_nmi3:.4f}, ARI={conf_ari3:.4f}, F1={conf_f1_3:.4f}, ACC={conf_acc3:.4f}")

            print(f"\nBest Venue Clustering Evaluation:")
            print(f"NMI: {best_conf_nmi:.4f}")
            print(f"ARI: {best_conf_ari:.4f}")
            print(f"F1: {best_conf_f1:.4f}")
            print(f"ACC: {best_conf_acc:.4f}")

            # Visualiser avec le même format que pour les auteurs
            visualize_clusters(
                conf_embeddings,
                conf_true_labels,
                best_conf_pred_labels,
                "Venue Cluster Visualization"
            )

            # Analyser les clusters de venues
            print("\nAnalyzing venue clusters...")
            conf_purity = analyze_clusters(conf_embeddings, conf_true_labels, best_conf_pred_labels, id_node_map)
            print(f"Venue Cluster Purity: {conf_purity:.4f}")

            # Sauvegarder les résultats des venues
            results_data['venue'] = {
                'num_nodes': len(conf_embeddings),
                'n_clusters': len(np.unique(conf_true_labels)),
                'nmi': best_conf_nmi,
                'ari': best_conf_ari,
                'f1': best_conf_f1,
                'acc': best_conf_acc,
                'purity': conf_purity,
                'best_method': 'Agglomerative Clustering (Multi-configuration)'
            }
        else:
            print("Pas d'étiquettes de domaine disponibles pour les venues.")

    # Calculer le temps d'exécution
    end_time = time.time()
    execution_time = end_time - start_time
    results_data['execution_time'] = f"{execution_time:.2f} seconds"

    # Estimer l'utilisation mémoire
    if torch.cuda.is_available():
        memory_usage = f"{torch.cuda.max_memory_allocated() / 1024**3:.2f} GB (GPU)"
    else:
        memory_usage = "CPU mode"
    results_data['memory_usage'] = memory_usage

    # Sauvegarder automatiquement le résumé des résultats
    print("\n" + "="*70)
    print("SAVING HIERARCHICAL CLUSTERING RESULTS SUMMARY")
    print("="*70)
    save_clustering_results_summary(results_data, output_dir)

    # Sauvegarder le modèle et les embeddings
    torch.save(model.state_dict(), 'hgt_model.pt')
    with open('embeddings.pkl', 'wb') as f:
        pickle.dump(embeddings, f)

    print("\nModèle et embeddings sauvegardés avec succès!")

    return model, embeddings, pred_labels

def evaluate_clustering_conference(embeddings, true_labels, n_clusters, pca_components=32, n_init_kmeans=30, n_runs=30):
    """
    Fonction spécialisée pour le clustering des venues utilisant uniquement le clustering hiérarchique
    avec alignement amélioré
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité pour améliorer le clustering
    from sklearn.decomposition import PCA
    pca = PCA(n_components=pca_components, random_state=42)
    embeddings_reduced = pca.fit_transform(embeddings)
    print(f"📊 Variance expliquée par PCA (venues): {sum(pca.explained_variance_ratio_):.4f}")

    # Exécuter le clustering hiérarchique avec différentes méthodes de liaison
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_alignment_quality = 0

    print(f"🔄 Testing hierarchical clustering configurations for venues...")

    for linkage in ['ward', 'complete', 'average', 'single']:
        agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
        pred_labels = agg.fit_predict(embeddings_reduced)

        nmi = normalized_mutual_info_score(true_labels, pred_labels)
        ari = adjusted_rand_score(true_labels, pred_labels)

        # Align predicted labels with true labels for F1 and Accuracy calculation
        aligned_labels = align_cluster_labels(true_labels, pred_labels)
        f1 = f1_score(true_labels, aligned_labels, average='weighted')
        acc = accuracy_score(true_labels, aligned_labels)

        # Calculate alignment quality
        alignment_mapping = create_cluster_alignment_mapping(true_labels, pred_labels)
        alignment_quality = calculate_alignment_quality(true_labels, pred_labels, alignment_mapping)

        print(f"   AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}, Alignment={alignment_quality:.4f}")

        # Select best result based on NMI primarily, with alignment quality as secondary criterion
        if nmi > best_nmi or (nmi == best_nmi and alignment_quality > best_alignment_quality):
            best_nmi = nmi
            best_ari = ari
            best_f1 = f1
            best_acc = acc
            best_labels = pred_labels
            best_alignment_quality = alignment_quality

    print(f"✅ Best venue configuration: NMI={best_nmi:.4f}, Alignment Quality={best_alignment_quality:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def evaluate_clustering_dbscan(embeddings, true_labels):
    """
    Utiliser le clustering hiérarchique pour les venues avec différents nombres de clusters
    """
    from sklearn.cluster import AgglomerativeClustering
    from sklearn.metrics import f1_score, accuracy_score

    # Convert embeddings to numpy if they're not already
    if isinstance(embeddings, torch.Tensor):
        embeddings = embeddings.detach().cpu().numpy()

    # Normaliser les embeddings
    embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    # Réduire la dimensionnalité
    try:
        from umap import UMAP
        print("Utilisation de UMAP pour la réduction de dimensionnalité...")
        reducer = UMAP(n_components=min(32, embeddings.shape[1]),
                      n_neighbors=min(15, embeddings.shape[0]-1),
                      min_dist=0.1,
                      random_state=42)
        embeddings_reduced = reducer.fit_transform(embeddings)
    except ImportError:
        # Fallback to PCA if UMAP is not available
        from sklearn.decomposition import PCA
        print("UMAP non disponible, utilisation de PCA...")
        pca = PCA(n_components=min(32, embeddings.shape[1]), random_state=42)
        embeddings_reduced = pca.fit_transform(embeddings)

    # Essayer différents nombres de clusters
    best_nmi = 0
    best_ari = 0
    best_f1 = 0
    best_acc = 0
    best_labels = None
    best_method = None

    # Essayer différents nombres de clusters
    n_clusters_list = [
        len(np.unique(true_labels)),
        len(np.unique(true_labels))-1,
        len(np.unique(true_labels))+1,
        len(np.unique(true_labels))-2,
        len(np.unique(true_labels))+2,
        max(3, len(np.unique(true_labels))//2),
        min(len(embeddings)//10, len(np.unique(true_labels))*2)
    ]

    for n_clusters in n_clusters_list:
        for linkage in ['ward', 'complete', 'average', 'single']:
            agg = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
            pred_labels = agg.fit_predict(embeddings_reduced)

            nmi = normalized_mutual_info_score(true_labels, pred_labels)
            ari = adjusted_rand_score(true_labels, pred_labels)

            # Align predicted labels with true labels for F1 and Accuracy calculation
            aligned_labels = align_cluster_labels(true_labels, pred_labels)
            f1 = f1_score(true_labels, aligned_labels, average='weighted')
            acc = accuracy_score(true_labels, aligned_labels)

            print(f"AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage}): NMI={nmi:.4f}, ARI={ari:.4f}, F1={f1:.4f}, ACC={acc:.4f}")

            if nmi > best_nmi:
                best_nmi = nmi
                best_ari = ari
                best_f1 = f1
                best_acc = acc
                best_labels = pred_labels
                best_method = f"AgglomerativeClustering (n_clusters={n_clusters}, linkage={linkage})"

    print(f"\nMeilleure méthode: {best_method}")
    print(f"NMI: {best_nmi:.4f}, ARI: {best_ari:.4f}, F1: {best_f1:.4f}, ACC: {best_acc:.4f}")

    return best_nmi, best_ari, best_f1, best_acc, best_labels

def get_node_domains(g, node_type, id_node_map, rdf_graph):
    """
    Extraire les domaines des nœuds à partir du graphe RDF
    """
    print(f"Extraction des domaines pour les nœuds de type '{node_type}'...")

    # Créer un vocabulaire des catégories
    category_vocab = {}
    for s, p, o in rdf_graph:
        if str(p) == "http://example.org/hasDomain":
            domain_uri = str(o)
            if domain_uri not in category_vocab:
                category_vocab[domain_uri] = len(category_vocab)

    # Initialiser les labels
    num_nodes = g.num_nodes(node_type)
    labels = np.zeros(num_nodes)

    # Pour chaque nœud, trouver son domaine
    for i in range(num_nodes):
        # Obtenir l'URI du nœud
        node_uri = id_node_map[int(g.nodes(node_type)[i])]

        # Chercher le domaine dans le graphe RDF
        for s, p, o in rdf_graph:
            if str(s) == node_uri and str(p) == "http://example.org/hasDomain":
                domain_uri = str(o)
                if domain_uri in category_vocab:
                    labels[i] = category_vocab[domain_uri]
                    break

    # Vérifier si des domaines ont été trouvés
    if np.all(labels == 0) and len(category_vocab) > 0:
        print(f"Aucun domaine trouvé pour les nœuds de type '{node_type}'. Essai avec publishesDomain...")

        # Essayer avec publishesDomain pour les conférences
        for i in range(num_nodes):
            node_uri = id_node_map[int(g.nodes(node_type)[i])]

            for s, p, o in rdf_graph:
                if str(s) == node_uri and str(p) == "http://example.org/publishesDomain":
                    domain_uri = str(o)
                    if domain_uri in category_vocab:
                        labels[i] = category_vocab[domain_uri]
                        break

    # Vérifier si des domaines ont été trouvés
    if np.all(labels == 0) and len(category_vocab) > 0:
        print(f"Aucun domaine trouvé pour les nœuds de type '{node_type}'. Utilisation de l'inférence...")

        # Inférer les domaines à partir des relations
        if node_type == 'venue':
            # Inférer les domaines des venues à partir des publications
            venue_domains = defaultdict(Counter)

            # Parcourir les publications et leurs venues
            for s, p, o in rdf_graph:
                if str(p) == "http://purl.org/dc/elements/1.1/isPartOf":
                    pub_uri = str(s)
                    venue_uri = str(o)

                    # Trouver le domaine de la publication
                    for s2, p2, o2 in rdf_graph:
                        if str(s2) == pub_uri and str(p2) == "http://example.org/hasDomain":
                            domain_uri = str(o2)
                            if domain_uri in category_vocab:
                                venue_domains[venue_uri][domain_uri] += 1

            # Assigner le domaine le plus fréquent à chaque venue
            for i in range(num_nodes):
                venue_uri = id_node_map[int(g.nodes(node_type)[i])]
                if venue_uri in venue_domains and venue_domains[venue_uri]:
                    most_common_domain = venue_domains[venue_uri].most_common(1)[0][0]
                    labels[i] = category_vocab[most_common_domain]

    # Vérifier si des domaines ont été trouvés
    found_domains = np.sum(labels != 0)
    print(f"Domaines trouvés pour {found_domains}/{num_nodes} nœuds de type '{node_type}'")

    if found_domains == 0:
        return None

    return labels

def get_true_labels(g, rdf_graph, id_node_map):
    """
    Get true labels based on research domains using hasDomain relation.

    Args:
        g: DGL graph
        rdf_graph: RDF graph containing domain information
        id_node_map: Mapping from node IDs to URIs

    Returns:
        labels: numpy array of labels for author nodes
        category_vocab: dictionary mapping domain URIs to numeric labels
    """
    # Créer le vocabulaire des domaines
    category_vocab = {}
    category_counter = 0
    for s, p, o in rdf_graph:
        if str(p) == "http://example.org/hasDomain":
            domain_uri = str(o)
            if domain_uri not in category_vocab:
                category_vocab[domain_uri] = category_counter
                category_counter += 1

    # Initialiser les labels pour les nœuds de type 'author'
    num_authors = g.number_of_nodes('author')
    labels = np.zeros(num_authors)

    # Pour chaque auteur, trouver son domaine
    for i in range(num_authors):
        # Obtenir l'URI de l'auteur
        author_uri = id_node_map[int(g.nodes('author')[i])]

        # Chercher le domaine dans le graphe RDF
        for s, p, o in rdf_graph:
            if str(s) == author_uri and str(p) == "http://example.org/hasDomain":
                domain_uri = str(o)
                if domain_uri in category_vocab:
                    labels[i] = category_vocab[domain_uri]
                    break

    return labels, category_vocab

# Add this before the analyze_graph_coverage() function definition
rdf_type_map = {
    "http://xmlns.com/foaf/0.1/Person": "author",
    "http://example.org/Publication": "publication",
    "http://example.org/Domain": "domain",
    "http://example.org/Conference": "conference",
    "http://example.org/Journal": "journal",
    "http://example.org/Venue": "venue"
}

def verify_relation_embeddings_usage(model, relation_embeddings):
    """
    Vérifie que les embeddings de relations sont bien utilisés
    """
    print("\nVérification des embeddings de relations:")
    print(f"Nombre d'embeddings chargés: {len(relation_embeddings)}")
    print("Dimensions des embeddings:")
    for etype, emb in relation_embeddings.items():
        print(f"  {etype}: {emb.shape}")

    # Vérifier que tous les types de relations du modèle ont un embedding
    model_etypes = set(model.G.etypes)
    emb_etypes = set(relation_embeddings.keys())
    missing = model_etypes - emb_etypes
    if missing:
        print(f"⚠️ Types de relations sans embeddings: {missing}")
    else:
        print("✅ Tous les types de relations ont des embeddings")

    # Vérifier les relations utilisées dans le graphe
    used_relations = set()
    for canonical_etype in model.G.canonical_etypes:
        _, etype, _ = canonical_etype
        used_relations.add(etype)
        src, dst = model.G.edges(etype=canonical_etype)
        print(f"  Relation {canonical_etype}: {len(src)} arêtes")

    # Vérifier quels embeddings sont effectivement utilisés
    used_embeddings = used_relations.intersection(emb_etypes)
    print(f"\nEmbeddings de relations effectivement utilisés: {len(used_embeddings)}/{len(emb_etypes)}")
    print(f"Relations utilisées: {sorted(list(used_embeddings))}")

    return used_embeddings

def analyze_graph_coverage():
    """
    Analyse la couverture du graphe RDF
    """
    # Compter tous les triplets
    total_triples = len(rdf_graph)

    # Analyser les types de nœuds
    node_type_counts = defaultdict(int)
    unmapped_types = set()

    for s in rdf_graph.subjects():
        type_found = False
        for p, o in rdf_graph.predicate_objects(subject=s):
            if 'type' in str(p).lower():
                type_uri = str(o)
                if type_uri in rdf_type_map:
                    node_type_counts[rdf_type_map[type_uri]] += 1
                    type_found = True
                else:
                    unmapped_types.add(type_uri)
        if not type_found:
            node_type_counts['unknown'] += 1

    # Analyser les relations
    relation_counts = defaultdict(int)
    unmapped_relations = set()

    for s, p, o in rdf_graph:
        if isinstance(s, URIRef) and isinstance(o, URIRef):
            pred = str(p)
            if "rdf-syntax-ns#type" not in pred:
                relation_counts[pred.split("/")[-1]] += 1

def cluster_publications_by_domain(g, embeddings, id_node_map):
    """
    Cluster publications and analyze their distribution across domains.
    """
    # Extraire les embeddings des publications et domaines
    pub_embeddings = embeddings['publication']
    domain_embeddings = embeddings['domain']

    # Normaliser les embeddings
    pub_embeddings = F.normalize(pub_embeddings, p=2, dim=1)
    domain_embeddings = F.normalize(domain_embeddings, p=2, dim=1)

    # Calculer la similarité entre publications et domaines
    similarity = torch.mm(pub_embeddings, domain_embeddings.t())

    # Assigner chaque publication au domaine le plus similaire
    _, domain_assignments = torch.max(similarity, dim=1)
    domain_assignments = domain_assignments.cpu().numpy()

    # Analyser les résultats
    print(f"Nombre de publications: {len(pub_embeddings)}")
    print(f"Nombre de domaines: {len(domain_embeddings)}")

    # Compter les publications par domaine
    domain_counts = Counter(domain_assignments)
    for domain_id, count in domain_counts.items():
        # Obtenir l'URI du domaine
        domain_node_id = g.nodes('domain')[domain_id]
        domain_uri = id_node_map[int(domain_node_id)]
        domain_name = domain_uri.split('/')[-1]
        print(f"Domaine {domain_name}: {count} publications")

    # Visualiser la distribution
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(domain_counts)), [count for _, count in sorted(domain_counts.items())])
    plt.xlabel('Domaine ID')
    plt.ylabel('Nombre de publications')
    plt.title('Distribution des publications par domaine')

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'publication_domain_distribution.png')
    plt.savefig(filepath, dpi=300)
    plt.close()

    return domain_assignments

def cluster_conferences_by_domain(g, embeddings, id_node_map):
    """
    Cluster venues and analyze their distribution across domains.
    """
    # Extraire les embeddings des venues et domaines
    conf_embeddings = embeddings['venue']
    domain_embeddings = embeddings['domain']

    # Normaliser les embeddings
    conf_embeddings = F.normalize(conf_embeddings, p=2, dim=1)
    domain_embeddings = F.normalize(domain_embeddings, p=2, dim=1)

    # Calculer la similarité entre venues et domaines
    similarity = torch.mm(conf_embeddings, domain_embeddings.t())

    # Assigner chaque venue au domaine le plus similaire
    _, domain_assignments = torch.max(similarity, dim=1)
    domain_assignments = domain_assignments.cpu().numpy()

    # Analyser les résultats
    print(f"Nombre de venues: {len(conf_embeddings)}")
    print(f"Nombre de domaines: {len(domain_embeddings)}")

    # Compter les venues par domaine
    domain_counts = Counter(domain_assignments)
    for domain_id, count in domain_counts.items():
        # Obtenir l'URI du domaine
        domain_node_id = g.nodes('domain')[domain_id]
        domain_uri = id_node_map[int(domain_node_id)]
        domain_name = domain_uri.split('/')[-1]
        print(f"Domaine {domain_name}: {count} venues")

    # Visualiser la distribution et la matrice de similarité
    plt.figure(figsize=(12, 10))

    # Distribution des venues par domaine
    plt.subplot(2, 1, 1)
    plt.bar(range(len(domain_counts)), [count for _, count in sorted(domain_counts.items())])
    plt.xlabel('Domaine ID')
    plt.ylabel('Nombre de venues')
    plt.title('Distribution des venues par domaine')

    # Heatmap de similarité entre venues et domaines
    plt.subplot(2, 1, 2)
    plt.imshow(similarity.cpu().numpy(), cmap='viridis', aspect='auto')
    plt.colorbar(label='Similarité cosinus')
    plt.xlabel('Domaines')
    plt.ylabel('Venues')
    plt.title('Similarité entre venues et domaines')

    plt.tight_layout()

    # Save in the output directory
    output_dir = create_output_directory()
    filepath = os.path.join(output_dir, 'venue_domain_analysis.png')
    plt.savefig(filepath, dpi=300)
    plt.close()

    return domain_assignments

if __name__ == "__main__":
    print("Démarrage du pipeline de clustering HGT...")

    # Chargement du graphe RDF
    rdf_graph = Graph()
    rdf_graph.parse("DBLP_petit.rdf")

    # Ajouter l'analyse de couverture
    analyze_graph_coverage()

    # Chargement des embeddings
    with open("node_features.pkl", "rb") as f:
        node_features = pickle.load(f)

    with open("relation_embeddings.pkl", "rb") as f:
        relation_embeddings = pickle.load(f)

    # === Détecter les types RDF de chaque entité
    # === Mapping explicite des types RDF vers noms clairs
    rdf_type_map = {
        "http://xmlns.com/foaf/0.1/Person": "author",
        "http://example.org/Publication": "publication",
        "http://example.org/Domain": "domain",
        "http://example.org/Conference": "conference",
        "http://example.org/Journal": "journal",
        "http://example.org/Venue": "venue"
    }

    # === Détection des types RDF de chaque entité avec mapping
    node_types = {}
    for s in rdf_graph.subjects():
        for p, o in rdf_graph.predicate_objects(subject=s):
            if 'type' in str(p).lower():
                mapped = rdf_type_map.get(str(o))
                if mapped:
                    node_types[str(s)] = mapped
                break  # stop at first type match

    # === Regrouper les arêtes par type de relation hétérogène
    edge_dict = defaultdict(lambda: ([], []))  # key: (src_type, relation, dst_type)
    # === Mapping explicite des classes RDF utilisées dans subClassOf
    class_uri_to_type = {
        "http://example.org/Conference": "conference",
        "http://example.org/Journal": "journal",
        "http://example.org/Venue": "venue"
    }
    # Filtrer uniquement les triplets URIRef -> URIRef
    for s, p, o in rdf_graph:
        if isinstance(s, URIRef) and isinstance(o, URIRef):
            # === Ignorer les relations rdf:type
            if "rdf-syntax-ns#type" in str(p):
                continue

            s_uri, p_uri, o_uri = str(s), str(p), str(o)

            # === Cas spécial : subClassOf → corriger les types
            if p_uri.endswith("subClassOf"):
                s_type = class_uri_to_type.get(s_uri, "venue")
                o_type = class_uri_to_type.get(o_uri, "venue")
                rel = "subClassOf"
                edge_dict[(s_type, rel, o_type)][0].append(s_uri)
                edge_dict[(s_type, rel, o_type)][1].append(o_uri)
                continue  # ne pas traiter ce triplet plus loin

            s_uri, p_uri, o_uri = str(s), str(p), str(o)
            s_type = node_types.get(s_uri, "venue")
            o_type = node_types.get(o_uri, "venue")
            rel = p_uri.split("/")[-1]  # ex: creator, isPartOf
            edge_dict[(s_type, rel, o_type)][0].append(s_uri)
            edge_dict[(s_type, rel, o_type)][1].append(o_uri)

    # === Créer un mapping global des identifiants de nœuds
    all_node_ids = set()
    for (srcs, dsts) in edge_dict.values():
        all_node_ids.update(srcs)
        all_node_ids.update(dsts)

    node_id_map = {uri: idx for idx, uri in enumerate(sorted(all_node_ids))}
    id_node_map = {v: k for k, v in node_id_map.items()}

    # === Construction du dictionnaire final pour DGL
    data_dict = {}
    for (srctype, reltype, dsttype), (srcs, dsts) in edge_dict.items():
        src_idx = [node_id_map[s] for s in srcs]
        dst_idx = [node_id_map[d] for d in dsts]
        data_dict[(srctype, reltype, dsttype)] = (src_idx, dst_idx)

    # === Création du graphe hétérogène DGL
    g = dgl.heterograph(data_dict)

    # === Ajout des features des nœuds (si disponibles)
    features = torch.zeros((len(node_id_map), 768))
    for uri, idx in node_id_map.items():
        if uri in node_features:
            features[idx] = node_features[uri]
    from collections import defaultdict

    # Étape 1 : regrouper les indices par type de nœud
    node_type_map = defaultdict(list)
    for uri, idx in node_id_map.items():
        ntype = node_types.get(uri, "venue").lower()
        node_type_map[ntype].append(idx)

    # Étape 2 : assigner les features par type de nœud
    from collections import defaultdict
    ndata_feats = {}
    for ntype in g.ntypes:
        nids = g.nodes(ntype)
        feats = []

        for nid in nids:
            uri = id_node_map[int(nid)]
            feat = node_features.get(uri, torch.zeros(768))
            feats.append(feat)

        ndata_feats[ntype] = torch.stack(feats)

    # Étape 2 : assigner les features par type de nœud
    g.ndata['feat'] = ndata_feats

    print(f"✅ Graphe DGL hétérogène construit avec {g.num_nodes()} nœuds et {g.num_edges()} arêtes.")
    print(f"Types de relations : {list(g.canonical_etypes)}")

    # Obtention des labels vrais basés sur hasDomain
    true_labels, domain_vocab = get_true_labels(g, rdf_graph, id_node_map)
    print(f"Nombre de classes (domaines) : {len(domain_vocab)}")
    print(f"Distribution des labels : {Counter(true_labels)}")

    # Pour voir la correspondance domaines-labels
    for domain, label in domain_vocab.items():
        print(f"Domaine: {domain.split('/')[-1]}, Label: {label}")

    # Préparation des embeddings de relations pour HGT
    print("\nChargement des embeddings de relations...")
    print(f"Clés disponibles dans relation_embeddings: {list(relation_embeddings.keys())}")

    # Mapping entre les noms courts utilisés dans le graphe et les URIs complètes
    relation_uri_map = {
        'creator': 'http://purl.org/dc/elements/1.1/creator',
        'subClassOf': 'http://www.w3.org/2000/01/rdf-schema#subClassOf',
        'domain_dominant': 'http://example.org/features/domain_dominant',
        'hasDomain': 'http://example.org/hasDomain',
        'publishesDomain': 'http://example.org/publishesDomain',
        'isPartOf': 'http://purl.org/dc/elements/1.1/isPartOf',
        'hasPublishedIn': 'http://example.org/hasPublishedIn'
    }

    hgt_relation_embeddings = {}
    for etype in g.etypes:
        if etype in relation_uri_map and relation_uri_map[etype] in relation_embeddings:
            hgt_relation_embeddings[etype] = relation_embeddings[relation_uri_map[etype]]
            print(f"✅ Found embedding for relation type '{etype}'")
        else:
            print(f"⚠️ No embedding found for relation type '{etype}'")
            # Créer un embedding basé sur le nom de la relation
            # Utiliser un modèle de texte simple pour encoder le nom
            from sentence_transformers import SentenceTransformer
            text_model = SentenceTransformer('all-MiniLM-L6-v2')
            embedding = text_model.encode(etype, convert_to_tensor=True)
            if embedding.shape[0] != 768:
                embedding = torch.nn.functional.pad(embedding, (0, 768 - embedding.shape[0]))
            hgt_relation_embeddings[etype] = embedding
            print(f"  Created embedding for '{etype}' based on its name")

    # Exécution du pipeline de clustering
    print("\nDémarrage du clustering...")
    model, embeddings, pred_labels = run_hgt_clustering(
        g, node_features, hgt_relation_embeddings, true_labels, id_node_map
    )

    # Vérification des embeddings de relations
    verify_relation_embeddings_usage(model, hgt_relation_embeddings)
# Out:
# Démarrage du pipeline de clustering HGT...
# ✅ Graphe DGL hétérogène construit avec 5292 nœuds et 5202 arêtes.
# Types de relations : [('author', 'domain_dominant', 'domain'), ('author', 'hasDomain', 'domain'), ('author', 'hasPublishedIn', 'venue'), ('publication', 'creator', 'author'), ('publication', 'isPartOf', 'venue'), ('venue', 'publishesDomain', 'domain')]
# Nombre de classes (domaines) : 11
# Distribution des labels : Counter({1.0: 195, 2.0: 147, 4.0: 139, 5.0: 119, 3.0: 117, 0.0: 98, 6.0: 96, 9.0: 94, 10.0: 63, 7.0: 56, 8.0: 41})
# Domaine: computervision, Label: 0
# Domaine: nlp, Label: 1
# Domaine: informationretrieval, Label: 2
# Domaine: softwareengineering, Label: 3
# Domaine: databases, Label: 4
# Domaine: datamining, Label: 5
# Domaine: machinelearning, Label: 6
# Domaine: deeplearning, Label: 7
# Domaine: artificialintelligence, Label: 8
# Domaine: bioinformatics, Label: 9
# Domaine: knowledgegraphs, Label: 10
#
# Chargement des embeddings de relations...
# Clés disponibles dans relation_embeddings: ['http://example.org/hasPublishedIn', 'http://www.w3.org/2000/01/rdf-schema#subClassOf', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://purl.org/dc/elements/1.1/creator', 'http://purl.org/dc/elements/1.1/isPartOf', 'http://example.org/hasDomain', 'http://example.org/features/domain_dominant', 'http://example.org/publishesDomain']
# ✅ Found embedding for relation type 'domain_dominant'
# ✅ Found embedding for relation type 'hasDomain'
# ✅ Found embedding for relation type 'hasPublishedIn'
# ✅ Found embedding for relation type 'creator'
# ✅ Found embedding for relation type 'isPartOf'
# ✅ Found embedding for relation type 'publishesDomain'
#
# Démarrage du clustering...
# Training HGT model...
# Training on cpu for 100 epochs...
# Epoch 10/100, Loss: 7.6939
# Learning rate: 0.000005
# Epoch 20/100, Loss: 7.4967
# Learning rate: 0.000005
# Epoch 30/100, Loss: 7.3542
# Learning rate: 0.000004
# Epoch 40/100, Loss: 7.1716
# Learning rate: 0.000003
# Epoch 50/100, Loss: 7.0596
# Learning rate: 0.000003
# Epoch 60/100, Loss: 6.8960
# Learning rate: 0.000002
# Epoch 70/100, Loss: 6.8822
# Learning rate: 0.000001
# Epoch 80/100, Loss: 6.8269
# Learning rate: 0.000000
# Epoch 90/100, Loss: 6.8283
# Learning rate: 0.000000
# Epoch 100/100, Loss: 6.7961
# Learning rate: 0.000000
#
# ==================================================
# CLUSTERING DES AUTEURS
# ==================================================
#
# Evaluating author clustering...
# 📊 Variance expliquée par PCA (author): 0.9206
# 🔄 Testing hierarchical clustering with different linkage methods for author...
#    AgglomerativeClustering (linkage=ward): NMI=0.9014, ARI=0.8688, F1=0.9205, ACC=0.9099, Alignment=0.9099
#    AgglomerativeClustering (linkage=complete): NMI=0.9140, ARI=0.8707, F1=0.9421, ACC=0.9339, Alignment=0.9339
#    AgglomerativeClustering (linkage=average): NMI=0.8899, ARI=0.8366, F1=0.9209, ACC=0.9107, Alignment=0.9107
#    AgglomerativeClustering (linkage=single): NMI=0.8866, ARI=0.8222, F1=0.8693, ACC=0.8567, Alignment=0.8567
# ✅ Best author clustering: NMI=0.9140, Alignment Quality=0.9339
#
# Author Clustering Evaluation:
# NMI: 0.9140
# ARI: 0.8707
# F1: 0.9421
# ACC: 0.9339
#
# Visualizing author clusters...
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Author Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 11
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 7: 55 nodes (Precision: 45.1%, Recall: 98.2%)
#    Cluster 1 ↔ Domain 6: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 2 ↔ Domain 4: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 3 ↔ Domain 2: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 4 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 5 ↔ Domain 5: 119 nodes (Precision: 94.4%, Recall: 100.0%)
#    Cluster 6 ↔ Domain 1: 167 nodes (Precision: 100.0%, Recall: 85.6%)
#    Cluster 7 ↔ Domain 9: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 8 ↔ Domain 10: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 9 ↔ Domain 8: 41 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 10 ↔ Domain 0: 98 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1088/1165 (93.4%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\author_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing author clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 122
# Dominant label: 7.0 (55 nodes, 45.1%)
# True label distribution:
#   Label 1.0: 25 nodes (20.5%)
#   Label 2.0: 11 nodes (9.0%)
#   Label 4.0: 8 nodes (6.6%)
#   Label 7.0: 55 nodes (45.1%)
#   Label 9.0: 23 nodes (18.9%)
#
# Cluster 1:
# Number of nodes: 94
# Dominant label: 6.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 1.0: 1 nodes (1.1%)
#   Label 6.0: 93 nodes (98.9%)
#
# Cluster 2:
# Number of nodes: 128
# Dominant label: 4.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 128 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 138
# Dominant label: 2.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 1.0: 2 nodes (1.4%)
#   Label 2.0: 136 nodes (98.6%)
#
# Cluster 4:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 126
# Dominant label: 5.0 (119 nodes, 94.4%)
# True label distribution:
#   Label 4.0: 3 nodes (2.4%)
#   Label 5.0: 119 nodes (94.4%)
#   Label 6.0: 3 nodes (2.4%)
#   Label 7.0: 1 nodes (0.8%)
#
# Cluster 6:
# Number of nodes: 167
# Dominant label: 1.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 167 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 71
# Dominant label: 9.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 9.0: 71 nodes (100.0%)
#
# Cluster 8:
# Number of nodes: 63
# Dominant label: 10.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 10.0: 63 nodes (100.0%)
#
# Cluster 9:
# Number of nodes: 41
# Dominant label: 8.0 (41 nodes, 100.0%)
# True label distribution:
#   Label 8.0: 41 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 98
# Dominant label: 0.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 98 nodes (100.0%)
#
# Overall cluster purity: 0.9339
# Author Cluster Purity: 0.9339
#
# ==================================================
# CLUSTERING DES PUBLICATIONS
# ==================================================
# Extraction des domaines pour les nœuds de type 'publication'...
# Domaines trouvés pour 1067/1443 nœuds de type 'publication'
#
# Evaluating publication clustering...
# 📊 Variance expliquée par PCA (publication): 0.8965
# 🔄 Testing hierarchical clustering with different linkage methods for publication...
#    AgglomerativeClustering (linkage=ward): NMI=0.8462, ARI=0.7132, F1=0.8596, ACC=0.8267, Alignment=0.8267
#    AgglomerativeClustering (linkage=complete): NMI=0.1887, ARI=-0.0481, F1=0.1095, ACC=0.1767, Alignment=0.1767
#    AgglomerativeClustering (linkage=average): NMI=0.1907, ARI=-0.0452, F1=0.1146, ACC=0.1802, Alignment=0.1802
#    AgglomerativeClustering (linkage=single): NMI=0.2108, ARI=0.0122, F1=0.2377, ACC=0.2973, Alignment=0.2973
# ✅ Best publication clustering: NMI=0.8462, Alignment Quality=0.8267
#
# Publication Clustering Evaluation:
# NMI: 0.8462
# ARI: 0.7132
# F1: 0.8596
# ACC: 0.8267
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Publication Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 11
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 0: 244 nodes (Precision: 100.0%, Recall: 64.9%)
#    Cluster 1 ↔ Domain 7: 55 nodes (Precision: 29.6%, Recall: 98.2%)
#    Cluster 2 ↔ Domain 1: 167 nodes (Precision: 100.0%, Recall: 85.6%)
#    Cluster 3 ↔ Domain 5: 119 nodes (Precision: 86.9%, Recall: 100.0%)
#    Cluster 4 ↔ Domain 4: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 5 ↔ Domain 2: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 6 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 7 ↔ Domain 6: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 8 ↔ Domain 8: 0 nodes (Precision: 0.0%, Recall: 0.0%)
#    Cluster 9 ↔ Domain 9: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 10 ↔ Domain 10: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1193/1443 (82.7%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\publication_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing publication clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 244
# Dominant label: 0.0 (244 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 244 nodes (100.0%)
#
# Cluster 1:
# Number of nodes: 186
# Dominant label: 7.0 (55 nodes, 29.6%)
# True label distribution:
#   Label 0.0: 23 nodes (12.4%)
#   Label 1.0: 25 nodes (13.4%)
#   Label 2.0: 11 nodes (5.9%)
#   Label 4.0: 8 nodes (4.3%)
#   Label 7.0: 55 nodes (29.6%)
#   Label 8.0: 41 nodes (22.0%)
#   Label 9.0: 23 nodes (12.4%)
#
# Cluster 2:
# Number of nodes: 167
# Dominant label: 1.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 167 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 137
# Dominant label: 5.0 (119 nodes, 86.9%)
# True label distribution:
#   Label 0.0: 11 nodes (8.0%)
#   Label 4.0: 3 nodes (2.2%)
#   Label 5.0: 119 nodes (86.9%)
#   Label 6.0: 3 nodes (2.2%)
#   Label 7.0: 1 nodes (0.7%)
#
# Cluster 4:
# Number of nodes: 128
# Dominant label: 4.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 128 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 138
# Dominant label: 2.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 1.0: 2 nodes (1.4%)
#   Label 2.0: 136 nodes (98.6%)
#
# Cluster 6:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 94
# Dominant label: 6.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 1.0: 1 nodes (1.1%)
#   Label 6.0: 93 nodes (98.9%)
#
# Cluster 8:
# Number of nodes: 98
# Dominant label: 0.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 98 nodes (100.0%)
#
# Cluster 9:
# Number of nodes: 71
# Dominant label: 9.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 9.0: 71 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 63
# Dominant label: 10.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 10.0: 63 nodes (100.0%)
#
# Overall cluster purity: 0.8947
# Publication Cluster Purity: 0.8947
#
# ==================================================
# CLUSTERING DES VENUES
# ==================================================
# Extraction des domaines pour les nœuds de type 'venue'...
# Domaines trouvés pour 1067/1508 nœuds de type 'venue'
#
# Evaluating venue clustering with specialized parameters...
#
# Testing configuration 1: More PCA components...
# 📊 Variance expliquée par PCA (venues): 0.9082
# 🔄 Testing hierarchical clustering configurations for venues...
#    AgglomerativeClustering (n_clusters=11, linkage=ward): NMI=0.8024, ARI=0.6064, F1=0.7928, ACC=0.7546, Alignment=0.7546
#    AgglomerativeClustering (n_clusters=11, linkage=complete): NMI=0.1626, ARI=-0.0712, F1=0.0931, ACC=0.1618, Alignment=0.1618
#    AgglomerativeClustering (n_clusters=11, linkage=average): NMI=0.1671, ARI=-0.0621, F1=0.1409, ACC=0.1943, Alignment=0.1943
#    AgglomerativeClustering (n_clusters=11, linkage=single): NMI=0.1820, ARI=-0.0154, F1=0.2373, ACC=0.2845, Alignment=0.2845
# ✅ Best venue configuration: NMI=0.8024, Alignment Quality=0.7546
# New best configuration (1): NMI=0.8024, ARI=0.6064, F1=0.7928, ACC=0.7546
#
# Testing configuration 2: Fewer clusters...
# 📊 Variance expliquée par PCA (venues): 0.8682
# 🔄 Testing hierarchical clustering configurations for venues...
#    AgglomerativeClustering (n_clusters=9, linkage=ward): NMI=0.7630, ARI=0.5102, F1=0.7452, ACC=0.7281, Alignment=0.7281
#    AgglomerativeClustering (n_clusters=9, linkage=complete): NMI=0.1660, ARI=-0.0661, F1=0.1263, ACC=0.1837, Alignment=0.1837
#    AgglomerativeClustering (n_clusters=9, linkage=average): NMI=0.2180, ARI=-0.0528, F1=0.1669, ACC=0.2135, Alignment=0.2135
#    AgglomerativeClustering (n_clusters=9, linkage=single): NMI=0.1823, ARI=-0.0149, F1=0.2379, ACC=0.2851, Alignment=0.2851
# ✅ Best venue configuration: NMI=0.7630, Alignment Quality=0.7281
#
# Testing configuration 3: Hierarchical clustering with different parameters...
# UMAP non disponible, utilisation de PCA...
# AgglomerativeClustering (n_clusters=11, linkage=ward): NMI=0.8024, ARI=0.6064, F1=0.7928, ACC=0.7546
# AgglomerativeClustering (n_clusters=11, linkage=complete): NMI=0.1628, ARI=-0.0710, F1=0.0854, ACC=0.1572
# AgglomerativeClustering (n_clusters=11, linkage=average): NMI=0.2147, ARI=-0.0596, F1=0.1451, ACC=0.1963
# AgglomerativeClustering (n_clusters=11, linkage=single): NMI=0.1817, ARI=-0.0159, F1=0.2368, ACC=0.2838
# AgglomerativeClustering (n_clusters=10, linkage=ward): NMI=0.7874, ARI=0.5702, F1=0.7506, ACC=0.7281
# AgglomerativeClustering (n_clusters=10, linkage=complete): NMI=0.1638, ARI=-0.0701, F1=0.0854, ACC=0.1572
# AgglomerativeClustering (n_clusters=10, linkage=average): NMI=0.2178, ARI=-0.0529, F1=0.1669, ACC=0.2135
# AgglomerativeClustering (n_clusters=10, linkage=single): NMI=0.1820, ARI=-0.0154, F1=0.2373, ACC=0.2845
# AgglomerativeClustering (n_clusters=12, linkage=ward): NMI=0.7859, ARI=0.5448, F1=0.7533, ACC=0.7115
# AgglomerativeClustering (n_clusters=12, linkage=complete): NMI=0.1623, ARI=-0.0713, F1=0.0854, ACC=0.1572
# AgglomerativeClustering (n_clusters=12, linkage=average): NMI=0.2139, ARI=-0.0602, F1=0.1451, ACC=0.1963
# AgglomerativeClustering (n_clusters=12, linkage=single): NMI=0.1817, ARI=-0.0159, F1=0.2368, ACC=0.2838
# AgglomerativeClustering (n_clusters=9, linkage=ward): NMI=0.7630, ARI=0.5102, F1=0.7452, ACC=0.7281
# AgglomerativeClustering (n_clusters=9, linkage=complete): NMI=0.1660, ARI=-0.0661, F1=0.1263, ACC=0.1837
# AgglomerativeClustering (n_clusters=9, linkage=average): NMI=0.2180, ARI=-0.0528, F1=0.1669, ACC=0.2135
# AgglomerativeClustering (n_clusters=9, linkage=single): NMI=0.1823, ARI=-0.0149, F1=0.2379, ACC=0.2851
# AgglomerativeClustering (n_clusters=13, linkage=ward): NMI=0.8102, ARI=0.5789, F1=0.7951, ACC=0.7480
# AgglomerativeClustering (n_clusters=13, linkage=complete): NMI=0.1613, ARI=-0.0723, F1=0.0854, ACC=0.1572
# AgglomerativeClustering (n_clusters=13, linkage=average): NMI=0.2131, ARI=-0.0606, F1=0.1451, ACC=0.1963
# AgglomerativeClustering (n_clusters=13, linkage=single): NMI=0.1814, ARI=-0.0165, F1=0.2362, ACC=0.2832
# AgglomerativeClustering (n_clusters=5, linkage=ward): NMI=0.5534, ARI=0.2216, F1=0.5060, ACC=0.5338
# AgglomerativeClustering (n_clusters=5, linkage=complete): NMI=0.1721, ARI=-0.0560, F1=0.1436, ACC=0.1963
# AgglomerativeClustering (n_clusters=5, linkage=average): NMI=0.2275, ARI=-0.0288, F1=0.2136, ACC=0.2566
# AgglomerativeClustering (n_clusters=5, linkage=single): NMI=0.1838, ARI=-0.0121, F1=0.2407, ACC=0.2885
# AgglomerativeClustering (n_clusters=22, linkage=ward): NMI=0.7848, ARI=0.5155, F1=0.7671, ACC=0.7036
# AgglomerativeClustering (n_clusters=22, linkage=complete): NMI=0.2025, ARI=-0.0730, F1=0.1103, ACC=0.1718
# AgglomerativeClustering (n_clusters=22, linkage=average): NMI=0.2047, ARI=-0.0709, F1=0.1103, ACC=0.1718
# AgglomerativeClustering (n_clusters=22, linkage=single): NMI=0.1786, ARI=-0.0217, F1=0.2304, ACC=0.2765
#
# Meilleure méthode: AgglomerativeClustering (n_clusters=13, linkage=ward)
# NMI: 0.8102, ARI: 0.5789, F1: 0.7951, ACC: 0.7480
# New best configuration (3): NMI=0.8102, ARI=0.5789, F1=0.7951, ACC=0.7480
#
# Best Venue Clustering Evaluation:
# NMI: 0.8102
# ARI: 0.5789
# F1: 0.7951
# ACC: 0.7480
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:768: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\PC\AppData\Local\Temp\ipykernel_12640\2266933361.py:774: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   plt.savefig(filepath, dpi=300, bbox_inches='tight')
# C:\Users\PC\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# === Venue Cluster Visualization - Enhanced Hierarchical Cluster Alignment Analysis ===
# Number of true domains: 11
# Number of predicted clusters: 13
# 🎨 Visual Enhancement: Corresponding clusters and domains use matching colors
#
# 🔗 Cluster-Domain Alignment Mapping:
#    Cluster 0 ↔ Domain 7: 55 nodes (Precision: 29.4%, Recall: 98.2%)
#    Cluster 1 ↔ Domain 0: 179 nodes (Precision: 100.0%, Recall: 40.6%)
#    Cluster 2 ↔ Domain 8: 0 nodes (Precision: 0.0%, Recall: 0.0%)
#    Cluster 3 ↔ Domain 1: 167 nodes (Precision: 100.0%, Recall: 85.6%)
#    Cluster 4 ↔ Domain 4: 128 nodes (Precision: 100.0%, Recall: 92.1%)
#    Cluster 5 ↔ Domain 5: 119 nodes (Precision: 86.9%, Recall: 100.0%)
#    Cluster 6 ↔ Domain 3: 117 nodes (Precision: 100.0%, Recall: 100.0%)
#    Cluster 8 ↔ Domain 6: 93 nodes (Precision: 98.9%, Recall: 96.9%)
#    Cluster 10 ↔ Domain 9: 71 nodes (Precision: 100.0%, Recall: 75.5%)
#    Cluster 11 ↔ Domain 2: 136 nodes (Precision: 98.6%, Recall: 92.5%)
#    Cluster 12 ↔ Domain 10: 63 nodes (Precision: 100.0%, Recall: 100.0%)
#
# ✅ Hierarchical Clustering Alignment Quality Metrics:
#    Total nodes correctly aligned: 1128/1508 (74.8%)
#    Number of optimal alignments: 11
# 📄 Hierarchical alignment report saved to: hierarchique hgt par type\venue_cluster_visualization_hierarchical_alignment_report.txt
#
# Analyzing venue clusters...
#
# Cluster Analysis:
# ----------------
#
# Cluster 0:
# Number of nodes: 187
# Dominant label: 7.0 (55 nodes, 29.4%)
# True label distribution:
#   Label 0.0: 24 nodes (12.8%)
#   Label 1.0: 25 nodes (13.4%)
#   Label 2.0: 11 nodes (5.9%)
#   Label 4.0: 8 nodes (4.3%)
#   Label 7.0: 55 nodes (29.4%)
#   Label 8.0: 41 nodes (21.9%)
#   Label 9.0: 23 nodes (12.3%)
#
# Cluster 1:
# Number of nodes: 179
# Dominant label: 0.0 (179 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 179 nodes (100.0%)
#
# Cluster 2:
# Number of nodes: 65
# Dominant label: 0.0 (65 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 65 nodes (100.0%)
#
# Cluster 3:
# Number of nodes: 167
# Dominant label: 1.0 (167 nodes, 100.0%)
# True label distribution:
#   Label 1.0: 167 nodes (100.0%)
#
# Cluster 4:
# Number of nodes: 128
# Dominant label: 4.0 (128 nodes, 100.0%)
# True label distribution:
#   Label 4.0: 128 nodes (100.0%)
#
# Cluster 5:
# Number of nodes: 137
# Dominant label: 5.0 (119 nodes, 86.9%)
# True label distribution:
#   Label 0.0: 11 nodes (8.0%)
#   Label 4.0: 3 nodes (2.2%)
#   Label 5.0: 119 nodes (86.9%)
#   Label 6.0: 3 nodes (2.2%)
#   Label 7.0: 1 nodes (0.7%)
#
# Cluster 6:
# Number of nodes: 117
# Dominant label: 3.0 (117 nodes, 100.0%)
# True label distribution:
#   Label 3.0: 117 nodes (100.0%)
#
# Cluster 7:
# Number of nodes: 64
# Dominant label: 0.0 (64 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 64 nodes (100.0%)
#
# Cluster 8:
# Number of nodes: 94
# Dominant label: 6.0 (93 nodes, 98.9%)
# True label distribution:
#   Label 1.0: 1 nodes (1.1%)
#   Label 6.0: 93 nodes (98.9%)
#
# Cluster 9:
# Number of nodes: 98
# Dominant label: 0.0 (98 nodes, 100.0%)
# True label distribution:
#   Label 0.0: 98 nodes (100.0%)
#
# Cluster 10:
# Number of nodes: 71
# Dominant label: 9.0 (71 nodes, 100.0%)
# True label distribution:
#   Label 9.0: 71 nodes (100.0%)
#
# Cluster 11:
# Number of nodes: 138
# Dominant label: 2.0 (136 nodes, 98.6%)
# True label distribution:
#   Label 1.0: 2 nodes (1.4%)
#   Label 2.0: 136 nodes (98.6%)
#
# Cluster 12:
# Number of nodes: 63
# Dominant label: 10.0 (63 nodes, 100.0%)
# True label distribution:
#   Label 10.0: 63 nodes (100.0%)
#
# Overall cluster purity: 0.8985
# Venue Cluster Purity: 0.8985
#
# ======================================================================
# SAVING HIERARCHICAL CLUSTERING RESULTS SUMMARY
# ======================================================================
#
# ✅ Clustering results summary saved to: hierarchique hgt par type\clustering_results_summary.txt
#
# Modèle et embeddings sauvegardés avec succès!
#
# Vérification des embeddings de relations:
# Nombre d'embeddings chargés: 6
# Dimensions des embeddings:
#   domain_dominant: torch.Size([768])
#   hasDomain: torch.Size([768])
#   hasPublishedIn: torch.Size([768])
#   creator: torch.Size([768])
#   isPartOf: torch.Size([768])
#   publishesDomain: torch.Size([768])
# ✅ Tous les types de relations ont des embeddings
#   Relation ('author', 'domain_dominant', 'domain'): 1165 arêtes
#   Relation ('author', 'hasDomain', 'domain'): 1165 arêtes
#   Relation ('author', 'hasPublishedIn', 'venue'): 1199 arêtes
#   Relation ('publication', 'creator', 'author'): 1340 arêtes
#   Relation ('publication', 'isPartOf', 'venue'): 267 arêtes
#   Relation ('venue', 'publishesDomain', 'domain'): 66 arêtes
#
# Embeddings de relations effectivement utilisés: 6/6
# Relations utilisées: ['creator', 'domain_dominant', 'hasDomain', 'hasPublishedIn', 'isPartOf', 'publishesDomain']
